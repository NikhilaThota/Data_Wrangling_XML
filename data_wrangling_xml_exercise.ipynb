# %% [markdown]
# # XML example and exercise
# ****
# + study examples of accessing nodes in XML tree structure
# + work on exercise to be completed and submitted
# ****
# + reference: https://docs.python.org/2.7/library/xml.etree.elementtree.html
# + data source: http://www.dbis.informatik.uni-goettingen.de/Mondial
# ****

# %%
import numpy as np
import pandas as pd
from xml.etree import ElementTree as ET

# %% [markdown]
# ## XML example
#
# + for details about tree traversal and iterators, see https://docs.python.org/2.7/library/xml.etree.elementtree.html

# %%
document_tree = ET.parse('E:\Data Science\Assignments\data_wrangling_xml\data\mondial_database_less.xml' )

# %%
# print names of all countries
for child in document_tree.getroot():
    print (child.find('name').text)
# Out:
# Albania
# Greece
# Macedonia
# Serbia
# Montenegro
# Kosovo
# Andorra

# %%
# print names of all countries and their cities
for element in document_tree.iterfind('country'):
    print('* ' + element.find('name').text + ':',)
    capitals_string = ''
    for subelement in element.getiterator('city'):
        capitals_string += subelement.find('name').text + ', '
    print(capitals_string[:-2])
# Out:
# * Albania:
# Tirana, Shkodër, Durrës, Vlorë, Elbasan, Korçë
# * Greece:
# Komotini, Kavala, Athina, Peiraias, Peristeri, Acharnes, Patra, Kozani, Kerkyra, Ioannina, Thessaloniki, Iraklio, Chania, Ermoupoli, Rhodes, Tripoli, Lamia, Chalkida, Larissa, Volos, Mytilini, Karyes
# * Macedonia:
# Skopje, Kumanovo
# * Serbia:
# Beograd, Novi Sad, Niš
# * Montenegro:
# Podgorica
# * Kosovo:
# Prishtine
# * Andorra:
# Andorra la Vella

# %% [markdown]
# ****
# ## XML exercise
#
# Using data in 'data/mondial_database.xml', the examples above, and refering to https://docs.python.org/2.7/library/xml.etree.elementtree.html, find
#
# 1. 10 countries with the lowest infant mortality rates
# 2. 10 cities with the largest population
# 3. 10 ethnic groups with the largest overall populations (sum of best/latest estimates over all countries)
# 4. name and country of a) longest river, b) largest lake and c) airport at highest elevation

# %%
document = ET.parse( 'E:\Data Science\Assignments\data_wrangling_xml\data\mondial_database.xml' )

# %% [markdown]
# # 1. 10 countries with the lowest infant mortality rates

# %%
# root is an instance of Element class
root = document.getroot()
root
# Out:
# <Element 'mondial' at 0x000001EDDEE03638>

# %%
# Create an empty dictionary lim
lim = {}
# Loop through each subelement in element country
for el in document.iter('country'):
    # Get the name of each country
    cntry = el.find('name')
    # Get the infant_mortality of each country
    inf = el.find('infant_mortality')
    if cntry is not None:
        if inf is not None:
            # Create a key value pair and fill the dictionary 
            lim[cntry.text] = float(inf.text)
        #else:
            #lim[cntry.text] = np.nan

# %%
lim
# Out:
# {'Afghanistan': 117.23,
#  'Albania': 13.19,
#  'Algeria': 21.76,
#  'American Samoa': 8.92,
#  'Andorra': 3.69,
#  'Angola': 79.99,
#  'Anguilla': 3.4,
#  'Antigua and Barbuda': 13.29,
#  'Argentina': 9.96,
#  'Armenia': 13.97,
#  'Aruba': 11.74,
#  'Australia': 4.43,
#  'Austria': 4.16,
#  'Azerbaijan': 26.67,
#  'Bahamas': 12.5,
#  'Bahrain': 9.68,
#  'Bangladesh': 45.67,
#  'Barbados': 10.93,
#  'Belarus': 3.64,
#  'Belgium': 4.18,
#  'Belize': 20.31,
#  'Benin': 57.09,
#  'Bermuda': 2.48,
#  'Bhutan': 37.89,
#  'Bolivia': 38.61,
#  'Bosnia and Herzegovina': 5.84,
#  'Botswana': 9.38,
#  'Brazil': 19.21,
#  'British Virgin Islands': 13.45,
#  'Brunei': 10.48,
#  'Bulgaria': 15.08,
#  'Burkina Faso': 76.8,
#  'Burundi': 63.44,
#  'Cambodia': 51.36,
#  'Cameroon': 55.1,
#  'Canada': 4.71,
#  'Cape Verde': 24.28,
#  'Cayman Islands': 6.21,
#  'Central African Republic': 92.86,
#  'Chad': 90.3,
#  'Chile': 7.02,
#  'China': 14.79,
#  'Colombia': 15.02,
#  'Comoros': 65.31,
#  'Congo': 59.34,
#  'Cook Islands': 14.33,
#  'Costa Rica': 8.7,
#  'Cote dIvoire': 60.16,
#  'Croatia': 5.87,
#  'Cuba': 4.7,
#  'Cyprus': 8.54,
#  'Czech Republic': 2.63,
#  'Denmark': 4.1,
#  'Djibouti': 50.2,
#  'Dominica': 11.61,
#  'Dominican Republic': 19.63,
#  'Ecuador': 17.93,
#  'Egypt': 22.41,
#  'El Salvador': 18.44,
#  'Equatorial Guinea': 71.12,
#  'Eritrea': 38.44,
#  'Estonia': 6.7,
#  'Ethiopia': 55.77,
#  'Faroe Islands': 5.71,
#  'Fiji': 10.2,
#  'Finland': 3.36,
#  'France': 3.31,
#  'French Guiana': 14.6,
#  'French Polynesia': 4.78,
#  'Gabon': 47.03,
#  'Gambia': 65.74,
#  'Gaza Strip': 30.6,
#  'Georgia': 16.68,
#  'Germany': 3.46,
#  'Ghana': 38.52,
#  'Gibraltar': 6.29,
#  'Greece': 4.78,
#  'Greenland': 9.42,
#  'Grenada': 10.5,
#  'Guadeloupe': 8.3,
#  'Guam': 5.51,
#  'Guatemala': 23.51,
#  'Guernsey': 3.47,
#  'Guinea': 55.24,
#  'Guinea-Bissau': 90.92,
#  'Guyana': 33.56,
#  'Haiti': 49.43,
#  'Honduras': 18.72,
#  'Hong Kong': 2.73,
#  'Hungary': 5.09,
#  'Iceland': 3.15,
#  'India': 43.19,
#  'Indonesia': 25.16,
#  'Iran': 39.0,
#  'Iraq': 37.53,
#  'Ireland': 3.74,
#  'Isle of Man': 4.17,
#  'Israel': 3.98,
#  'Italy': 3.31,
#  'Jamaica': 13.69,
#  'Japan': 2.13,
#  'Jersey': 3.86,
#  'Jordan': 15.73,
#  'Kazakhstan': 21.61,
#  'Kenya': 40.71,
#  'Kiribati': 35.37,
#  'Kuwait': 7.51,
#  'Kyrgyzstan': 28.71,
#  'Laos': 54.53,
#  'Latvia': 7.91,
#  'Lebanon': 7.98,
#  'Lesotho': 50.48,
#  'Liberia': 69.19,
#  'Libya': 11.87,
#  'Liechtenstein': 4.33,
#  'Lithuania': 6.0,
#  'Luxembourg': 4.28,
#  'Macao': 3.13,
#  'Macedonia': 7.9,
#  'Madagascar': 44.88,
#  'Malawi': 48.01,
#  'Malaysia': 13.69,
#  'Maldives': 24.59,
#  'Mali': 104.34,
#  'Malta': 3.59,
#  'Marshall Islands': 21.39,
#  'Martinique': 7.1,
#  'Mauritania': 56.06,
#  'Mauritius': 10.59,
#  'Mayotte': 56.29,
#  'Mexico': 12.58,
#  'Micronesia': 21.93,
#  'Moldova': 12.93,
#  'Monaco': 1.81,
#  'Mongolia': 23.15,
#  'Montserrat': 13.66,
#  'Morocco': 24.52,
#  'Mozambique': 72.42,
#  'Myanmar': 44.91,
#  'Namibia': 45.64,
#  'Nauru': 8.21,
#  'Nepal': 40.43,
#  'Netherlands': 3.66,
#  'New Caledonia': 5.46,
#  'New Zealand': 4.59,
#  'Nicaragua': 20.36,
#  'Niger': 86.27,
#  'Nigeria': 74.09,
#  'North Korea': 24.5,
#  'Northern Mariana Islands': 5.5,
#  'Norway': 2.48,
#  'Oman': 14.0,
#  'Pakistan': 57.48,
#  'Palau': 11.46,
#  'Panama': 10.7,
#  'Papua New Guinea': 39.67,
#  'Paraguay': 20.75,
#  'Peru': 20.21,
#  'Philippines': 17.64,
#  'Poland': 6.19,
#  'Portugal': 4.48,
#  'Puerto Rico': 7.73,
#  'Qatar': 6.42,
#  'Reunion': 7.5,
#  'Romania': 10.16,
#  'Russia': 7.08,
#  'Rwanda': 59.59,
#  'Saint Helena': 17.63,
#  'Saint Kitts and Nevis': 8.98,
#  'Saint Lucia': 11.75,
#  'Saint Pierre and Miquelon': 6.95,
#  'Saint Vincent and the Grenadines': 13.07,
#  'Samoa': 20.5,
#  'San Marino': 4.52,
#  'Sao Tome and Principe': 49.16,
#  'Saudi Arabia': 14.58,
#  'Senegal': 52.72,
#  'Serbia': 6.16,
#  'Seychelles': 10.77,
#  'Sierra Leone': 73.29,
#  'Singapore': 2.53,
#  'Sint Maarten': 9.05,
#  'Slovakia': 5.35,
#  'Slovenia': 4.04,
#  'Solomon Islands': 16.17,
#  'Somalia': 100.14,
#  'South Africa': 41.61,
#  'South Korea': 3.93,
#  'South Sudan': 68.16,
#  'Spain': 3.33,
#  'Sri Lanka': 9.02,
#  'Sudan': 52.86,
#  'Suriname': 27.07,
#  'Swaziland': 54.82,
#  'Sweden': 2.6,
#  'Switzerland': 3.73,
#  'Syria': 15.79,
#  'Taiwan': 4.49,
#  'Tajikistan': 35.03,
#  'Tanzania': 43.74,
#  'Thailand': 9.86,
#  'Timor-Leste': 38.79,
#  'Togo': 46.73,
#  'Tonga': 12.36,
#  'Trinidad and Tobago': 24.82,
#  'Tunisia': 23.19,
#  'Turkey': 21.43,
#  'Turkmenistan': 38.13,
#  'Turks and Caicos Islands': 10.97,
#  'Tuvalu': 31.69,
#  'Uganda': 60.82,
#  'Ukraine': 8.1,
#  'United Arab Emirates': 10.92,
#  'United Kingdom': 4.44,
#  'United States': 6.17,
#  'Uruguay': 8.97,
#  'Uzbekistan': 19.84,
#  'Vanuatu': 16.41,
#  'Venezuela': 19.33,
#  'Vietnam': 18.99,
#  'Virgin Islands': 6.79,
#  'Wallis and Futuna': 4.49,
#  'West Bank': 28.6,
#  'Western Sahara': 145.82,
#  'Yemen': 50.41,
#  'Zaire': 73.15,
#  'Zambia': 66.62,
#  'Zimbabwe': 26.55}

# %%
# Create a DataFrame (infdf) from the dictionary (lim)
infdf = pd.DataFrame(list(lim.items()), columns=['Country', 'Infant_Mortality'])

# %%
infdf
# Out:
#                     Country  Infant_Mortality
# 0                   Albania             13.19
# 1                    Greece              4.78
# 2                 Macedonia              7.90
# 3                    Serbia              6.16
# 4                   Andorra              3.69
# 5                    France              3.31
# 6                     Spain              3.33
# 7                   Austria              4.16
# 8            Czech Republic              2.63
# 9                   Germany              3.46
# 10                  Hungary              5.09
# 11                    Italy              3.31
# 12            Liechtenstein              4.33
# 13                 Slovakia              5.35
# 14                 Slovenia              4.04
# 15              Switzerland              3.73
# 16                  Belarus              3.64
# 17                   Latvia              7.91
# 18                Lithuania              6.00
# 19                   Poland              6.19
# 20                  Ukraine              8.10
# 21                   Russia              7.08
# 22                  Belgium              4.18
# 23               Luxembourg              4.28
# 24              Netherlands              3.66
# 25   Bosnia and Herzegovina              5.84
# 26                  Croatia              5.87
# 27                 Bulgaria             15.08
# 28                  Romania             10.16
# 29                   Turkey             21.43
# ..                      ...               ...
# 198                    Chad             90.30
# 199       Equatorial Guinea             71.12
# 200                   Gabon             47.03
# 201              Cape Verde             24.28
# 202                   Sudan             52.86
# 203             South Sudan             68.16
# 204                 Comoros             65.31
# 205                  Guinea             55.24
# 206                 Liberia             69.19
# 207                Djibouti             50.20
# 208                 Eritrea             38.44
# 209                Ethiopia             55.77
# 210                 Somalia            100.14
# 211                   Kenya             40.71
# 212                  Gambia             65.74
# 213                 Senegal             52.72
# 214           Guinea-Bissau             90.92
# 215            Sierra Leone             73.29
# 216                  Uganda             60.82
# 217                 Lesotho             50.48
# 218              Madagascar             44.88
# 219                  Malawi             48.01
# 220              Mozambique             72.42
# 221               Mauritius             10.59
# 222                 Mayotte             56.29
# 223               Swaziland             54.82
# 224                 Reunion              7.50
# 225            Saint Helena             17.63
# 226   Sao Tome and Principe             49.16
# 227              Seychelles             10.77
#
# [228 rows x 2 columns]

# %%
# Sort the countries with lowest infant mortality rates and display the first 'ten' in the list
infdf = infdf.sort_values('Infant_Mortality').head(10)
infdf
# Out:
#             Country  Infant_Mortality
# 36           Monaco              1.81
# 90            Japan              2.13
# 109         Bermuda              2.48
# 34           Norway              2.48
# 98        Singapore              2.53
# 35           Sweden              2.60
# 8    Czech Republic              2.63
# 72        Hong Kong              2.73
# 73            Macao              3.13
# 39          Iceland              3.15

# %% [markdown]
# # 2. 10 cities with the largest population

# %%
# Looking carefully at the XML Document tree, one can notice that some cities are subelements to the subelement province.
# To retrieve those cities and population I defined the path "./country/province/city"
#Create a dictionary 'provdict'
provdict = {}
for cty in document.findall("./country/province/city"):
    # Retreive all the names of the cities, and corresponding population figures
    name = cty.find('name')
    pop = cty.findall('population')
    if pop:
        # To retrieve the most recent year's population
        provdict[name.text] = int(pop[len(pop)-1].text)

# %%
provdict
# Out:
# {'Kavala': 58790,
#  'Athina': 664046,
#  'Peiraias': 163688,
#  'Peristeri': 139981,
#  'Acharnes': 106943,
#  'Patra': 213984,
#  'Kerkyra': 102071,
#  'Ioannina': 112486,
#  'Thessaloniki': 325182,
#  'Iraklio': 173993,
#  'Chania': 108642,
#  'Rhodes': 115490,
#  'Lamia': 75315,
#  'Chalkida': 102223,
#  'Larissa': 162591,
#  'Volos': 144449,
#  'Karyes': 233,
#  'Strasbourg': 272222,
#  'Mulhouse': 110351,
#  'Bordeaux': 239399,
#  'Clermont-Ferrand': 140957,
#  'Caen': 108793,
#  'Rennes': 208033,
#  'Brest': 309764,
#  'Dijon': 151672,
#  'Orléans': 114185,
#  'Tours': 134633,
#  'Reims': 180752,
#  'Ajaccio': 66245,
#  'Besançon': 115879,
#  'Rouen': 111553,
#  'Le Havre': 174156,
#  'Paris': 2249975,
#  'Boulogne-Billancourt': 116220,
#  'Argenteuil': 104282,
#  'Montreuil': 103068,
#  'Saint-Paul': 103916,
#  'Montpellier': 264538,
#  'Nîmes': 144940,
#  'Perpignan': 118238,
#  'Limoges': 137758,
#  'Metz': 119962,
#  'Nancy': 105382,
#  'Toulouse': 447340,
#  'Lille': 227533,
#  'Nantes': 287845,
#  'Angers': 148803,
#  'Le Mans': 143240,
#  'Amiens': 133327,
#  'Poitiers': 87646,
#  'Marseille': 850636,
#  'Nice': 344064,
#  'Toulon': 163974,
#  'Aix-en-Provence': 140684,
#  'Lyon': 491268,
#  'Grenoble': 157424,
#  'Saint-Étienne': 170049,
#  'Villeurbanne': 145034,
#  'Sevilla': 698042,
#  'Almería': 189680,
#  'Cádiz': 124014,
#  'Córdoba': 1267774,
#  'Granada': 241003,
#  'Huelva': 147808,
#  'Málaga': 561435,
#  'Jerez de la Frontera': 211784,
#  'Jaén': 116469,
#  'Algeciras': 117695,
#  'Marbella': 135124,
#  'Dos Hermanas': 128433,
#  'Zaragoza': 678115,
#  'Oviedo': 225005,
#  'Gijón': 276969,
#  'Palma de Mallorca': 402044,
#  'Vitoria-Gasteiz': 240753,
#  'Bilbao': 351356,
#  'Barakaldo': 100064,
#  'Donostia': 185512,
#  'Santa Cruz de Tenerife': 204476,
#  'San Cristóbal de La Laguna': 152025,
#  'Las Palmas de Gran Canaria': 381271,
#  'Telde': 101080,
#  'Santander': 178095,
#  'Valladolid': 311682,
#  'Burgos': 178864,
#  'León': 1238962,
#  'Salamanca': 160169,
#  'Albacete': 171999,
#  'Barcelona': 410643,
#  'Lleida': 137283,
#  'Tarragona': 133223,
#  'Reus': 106849,
#  'Hospitalet de Llobregat': 256509,
#  'Badalona': 219241,
#  'Sabadell': 206949,
#  'Terrassa': 214406,
#  'Santa Coloma de Gramenet': 119391,
#  'Mataró': 123367,
#  'Badajoz': 151214,
#  'A Coruña': 245053,
#  'Vigo': 295623,
#  'Ourense': 107314,
#  'Madrid': 3198645,
#  'Móstoles': 203493,
#  'Leganés': 185758,
#  'Alcalá de Henares': 200505,
#  'Fuenlabrada': 196986,
#  'Getafe': 168642,
#  'Alcorcón': 167217,
#  'Torrejón de Ardoz': 123213,
#  'Parla': 122045,
#  'Alcobendas': 110351,
#  'Murcia': 437667,
#  'Cartagena': 990179,
#  'Pamplona': 195943,
#  'Logroño': 152698,
#  'Valencia': 832229,
#  'Alicante': 329325,
#  'Elche': 227417,
#  'Castellón de la Plana': 176298,
#  'Eisenstadt': 13485,
#  'Klagenfurt': 96531,
#  'Villach': 59942,
#  'Wien': 1761738,
#  'Linz': 193511,
#  'Wels': 59239,
#  'Innsbruck': 124386,
#  'Graz': 269211,
#  'Salzburg': 146676,
#  'St. Pölten': 52100,
#  'Praha': 1289556,
#  'České Budějovice': 95589,
#  'Brno': 404820,
#  'Karlovy Vary': 53310,
#  'Jihlava': 51162,
#  'Hradec Králové': 95594,
#  'Liberec': 104973,
#  'Ostrava': 311508,
#  'Olomouc': 101954,
#  'Pardubice': 90844,
#  'Plzeň': 171346,
#  'Ústí nad Labem': 98596,
#  'Zlín': 77137,
#  'Stuttgart': 585890,
#  'Mannheim': 290117,
#  'Karlsruhe': 289173,
#  'Freiburg': 209628,
#  'Heidelberg': 146751,
#  'Heilbronn': 116059,
#  'Pforzheim': 114411,
#  'Ulm': 116761,
#  'Reutlingen': 109799,
#  'München': 1348335,
#  'Nürnberg': 486314,
#  'Augsburg': 267767,
#  'Würzburg': 124297,
#  'Regensburg': 135403,
#  'Ingolstadt': 124927,
#  'Fürth': 115613,
#  'Erlangen': 103719,
#  'Berlin': 3292365,
#  'Potsdam': 156021,
#  'Cottbus': 99984,
#  'Bremen': 542707,
#  'Bremerhaven': 108156,
#  'Hamburg': 1706696,
#  'Wiesbaden': 269121,
#  'Frankfurt am Main': 667925,
#  'Kassel': 190765,
#  'Darmstadt': 143499,
#  'Offenbach am Main': 113443,
#  'Schwerin': 91293,
#  'Rostock': 200265,
#  'Hannover': 506416,
#  'Braunschweig': 242537,
#  'Osnabrück': 153699,
#  'Oldenburg': 157267,
#  'Göttingen': 115843,
#  'Wolfsburg': 119984,
#  'Salzgitter': 98895,
#  'Hildesheim': 99554,
#  'Düsseldorf': 586291,
#  'Köln': 1005775,
#  'Essen': 566201,
#  'Dortmund': 571143,
#  'Duisburg': 488468,
#  'Bochum': 362286,
#  'Wuppertal': 342661,
#  'Bielefeld': 326870,
#  'Gelsenkirchen': 258766,
#  'Bonn': 305765,
#  'Mönchengladbach': 255188,
#  'Münster': 289576,
#  'Krefeld': 222247,
#  'Aachen': 236420,
#  'Oberhausen': 210216,
#  'Hagen': 187944,
#  'Hamm': 176037,
#  'Herne': 155160,
#  'Mülheim an der Ruhr': 166865,
#  'Solingen': 155265,
#  'Leverkusen': 158984,
#  'Neuss': 150568,
#  'Paderborn': 142365,
#  'Recklinghausen': 115958,
#  'Remscheid': 110708,
#  'Bottrop': 117311,
#  'Siegen': 99187,
#  'Moers': 104009,
#  'Witten': 96382,
#  'Bergisch Gladbach': 108878,
#  'Mainz': 200344,
#  'Ludwigshafen': 157584,
#  'Koblenz': 107825,
#  'Kaiserslautern': 96340,
#  'Trier': 105671,
#  'Saarbrücken': 175853,
#  'Dresden': 512354,
#  'Leipzig': 502979,
#  'Chemnitz': 240253,
#  'Zwickau': 93081,
#  'Magdeburg': 228144,
#  'Halle': 229153,
#  'Kiel': 235782,
#  'Lübeck': 210305,
#  'Erfurt': 200868,
#  'Gera': 96067,
#  'Jena': 105739,
#  'Pécs': 156049,
#  'Kecskemét': 111411,
#  'Békéscsaba': 62050,
#  'Miskolc': 167754,
#  'Szeged': 168048,
#  'Székesfehérvár': 100570,
#  'Győr': 129527,
#  'Debrecen': 211320,
#  'Eger': 56569,
#  'Tatabánya': 67753,
#  'Kaposvár': 66245,
#  'Nyíregyháza': 119746,
#  'Szolnok': 72953,
#  'Szombathely': 78884,
#  'Veszprém': 61721,
#  'Zalaegerszeg': 59499,
#  'Budapest': 1729040,
#  'Novara': 101952,
#  'Torino': 872367,
#  'Bérgamo': 115349,
#  'Bréscia': 189902,
#  'Milano': 1242123,
#  'Monza': 119856,
#  'Bolzano': 102575,
#  'Trento': 114198,
#  'Pádova': 206192,
#  'Verona': 252520,
#  'Vicenza': 111500,
#  'Venézia': 261362,
#  'Trieste': 202123,
#  'La Spezia': 92659,
#  'Génova': 586180,
#  'Bologna': 371337,
#  'Ferrara': 132545,
#  'Forlí': 116434,
#  'Módena': 179149,
#  'Parma': 175895,
#  'Piacenza': 100311,
#  'Ravenna': 153740,
#  "Réggio nell'Emilia": 162082,
#  'Rímini': 139601,
#  'Livorno': 157052,
#  'Pisa': 85858,
#  'Firenze': 358079,
#  'Prato': 185456,
#  'Perúgia': 162449,
#  'Terni': 109193,
#  'Ancona': 100497,
#  'Roma': 2617175,
#  'Latina': 117892,
#  'Pescara': 117166,
#  'Salerno': 132608,
#  'Nápoli': 962003,
#  'Torre del Greco': 85922,
#  'Giugliano in Campania': 108793,
#  'Bari': 315933,
#  'Fóggia': 147036,
#  'Lecce': 89916,
#  'Andria': 100052,
#  'Táranto': 200154,
#  'Catanzaro': 89364,
#  'Cosenza': 69484,
#  'Réggio di Calabria': 180817,
#  'Palermo': 657561,
#  'Messina': 243262,
#  'Catánia': 293902,
#  'Siracusa': 118385,
#  'Cágliari': 149883,
#  'Sássari': 123782,
#  'Bratislava': 411228,
#  'Banská Bystrica': 80003,
#  'Žilina': 81494,
#  'Košice': 240433,
#  'Prešov': 91782,
#  'Nitra': 78916,
#  'Trenčín': 55877,
#  'Trnava': 66358,
#  'Basel': 167386,
#  'Bern': 128848,
#  'Biel': 53031,
#  'Genève': 191557,
#  'Luzern': 80501,
#  'Sankt Gallen': 74581,
#  'Lugano': 62792,
#  'Lausanne': 132788,
#  'Zürich': 384786,
#  'Winterthur': 105676,
#  'Vitebsk': 347928,
#  'Gomel': 482652,
#  'Grodno': 327540,
#  'Mogilev': 358279,
#  'Bobruysk': 215092,
#  'Minsk': 1836808,
#  'Wrocław': 631377,
#  'Legnica': 102708,
#  'Wałbrzych': 119216,
#  'Bydgoszcz': 362286,
#  'Toruń': 204847,
#  'Grudziadz': 98726,
#  'Włocławek': 115982,
#  'Lublin': 348120,
#  'Zielona Góra': 119182,
#  'Gorzów Wielkopolski': 124470,
#  'Łódź': 722022,
#  'Kraków': 759131,
#  'Tarnów': 113188,
#  'Warszawa': 1711324,
#  'Płock': 124048,
#  'Radom': 220062,
#  'Opole': 122120,
#  'Rzeszów': 180776,
#  'Białystok': 294675,
#  'Gdańsk': 460354,
#  'Gdynia': 248574,
#  'Katowice': 308269,
#  'Jastrzebie Zdroj': 92465,
#  'Sosnowiec': 214488,
#  'Dąbrowa Górnicza': 125063,
#  'Bytom': 175377,
#  'Gliwice': 186347,
#  'Zabrze': 179861,
#  'Tychy': 129087,
#  'Ruda Śląska': 142672,
#  'Rybnik': 140863,
#  'Chorzów': 111314,
#  'Częstochowa': 235156,
#  'Bielsko-Biała': 174291,
#  'Kielce': 201363,
#  'Olsztyn': 175482,
#  'Elbląg': 123977,
#  'Poznań': 552393,
#  'Kalisz': 104867,
#  'Szczecin': 409211,
#  'Koszalin': 109183,
#  'Cherkasy': 286163,
#  'Chernihiv': 296723,
#  'Chernivtsi': 255929,
#  'Dnipropetrovs´k': 999577,
#  'Kryvyi Rih': 660203,
#  'Dniprodzerzhyns´k': 242646,
#  'Nikopol´': 120000,
#  'Donets´k': 955041,
#  'Mariupol´': 464457,
#  'Makiïvka': 356118,
#  'Horlivka': 258879,
#  'Kramators´k': 165469,
#  'Ivano-Frankivs´k': 224660,
#  'Kharkiv': 1441362,
#  'Kherson': 300666,
#  'Khmel´nyts´kyi': 263703,
#  'Prypjat': 0,
#  'Kirovohrad': 234919,
#  'Luhans´k': 427187,
#  'L´viv': 729842,
#  'Mykolaïv': 497032,
#  'Odesa': 1008162,
#  'Poltava': 297589,
#  'Kremenchuk': 226434,
#  'Rivne': 250174,
#  'Sumy': 269663,
#  'Ternopil´': 217300,
#  'Vinnytsia': 370814,
#  'Luts´k': 213063,
#  'Uzhhorod': 116556,
#  'Zaporizhzhia': 772627,
#  'Melitopol´': 156885,
#  'Zhytomyr': 271895,
#  'Simferopol´': 335582,
#  'Kerch': 145845,
#  'Kyïv': 2814258,
#  'Bila Tserkva': 210551,
#  'Sevastopol´': 340559,
#  'Petrozavodsk': 268946,
#  'Syktyvkar': 235006,
#  'Ukhta': 99591,
#  'Vorkuta': 70548,
#  'Arkhangelsk': 350985,
#  'Severodvinsk': 192353,
#  'Vologda': 306487,
#  'Cherepovets': 315738,
#  'Murmansk': 302468,
#  'Kaliningrad': 441376,
#  'Sankt Peterburg': 5028000,
#  'Velikij Novgorod': 218717,
#  'Pskov': 203279,
#  'Bryansk': 410837,
#  'Vladimir': 347930,
#  'Kovrov': 145214,
#  'Murom': 116075,
#  'Ivanovo': 409075,
#  'Kaluga': 331351,
#  'Obninsk': 104739,
#  'Kostroma': 271445,
#  'Moskva': 11979529,
#  "Podol'sk": 187961,
#  'Železnodorožnyj': 131257,
#  'Krasnogorsk': 116896,
#  "L'ubercy": 172525,
#  'Kolomna': 144589,
#  'Mytišči': 173160,
#  "Elektrostal'": 155196,
#  'Serpuchov': 127041,
#  'Balašicha': 215494,
#  'Chimki': 207425,
#  'Odincovo': 138930,
#  'Orechovo-Zujevo': 120670,
#  'Noginsk': 100072,
#  'Ščëlkovo': 110411,
#  'Sergijev Posad': 111179,
#  'Korolëv': 183402,
#  'Žukovskij': 104736,
#  'Puškino': 102874,
#  'Orel': 318136,
#  'Ryazan': 527905,
#  'Smolensk': 330970,
#  'Tver': 408877,
#  'Tula': 493813,
#  'Novomoskovsk': 131386,
#  'Yaroslavl': 599169,
#  'Rybinsk': 200771,
#  'Yoshkar-Ola': 257015,
#  'Saransk': 298287,
#  'Cheboksary': 464940,
#  'Novočeboksarsk': 124097,
#  'Kirov': 483176,
#  'Nizhnii Novgorod': 1259921,
#  'Dzeržinsk': 240742,
#  'Arzamas': 106362,
#  'Belgorod': 373528,
#  'Staryj Oskol': 221085,
#  'Voronezh': 1003638,
#  'Kursk': 428741,
#  'Lipetsk': 509098,
#  'Jelec': 108404,
#  'Tambov': 281834,
#  'Elista': 103749,
#  'Kazan': 1176187,
#  'Naberezhnye Tchelny': 519025,
#  'Nižnekamsk': 234044,
#  "Al'metjevsk": 146393,
#  'Astrakhan': 527345,
#  'Volgograd': 1018790,
#  'Volzhsky': 327356,
#  'Kamyšin': 119565,
#  'Penza': 519900,
#  'Samara': 1171598,
#  'Tolyatti': 719149,
#  "Syzran'": 178750,
#  'Novokujbyševsk': 108438,
#  'Saratov': 839755,
#  'Balakovo': 199690,
#  "Ėngel's": 202419,
#  'Ulyanovsk': 615306,
#  'Dimitrovgrad': 122580,
#  'Rostov-na-Donu': 1103733,
#  'Batajsk': 111843,
#  'Taganrog': 254783,
#  'Šachty': 239987,
#  'Novočerkassk': 168746,
#  'Volgodonsk': 170841,
#  'Novošachtinsk': 111075,
#  'Ufa': 1077719,
#  'Sterlitamak': 275798,
#  'Salavat': 156095,
#  "Okt'abr'skij": 109474,
#  'Izhevsk': 632913,
#  'Sarapul': 101381,
#  'Orenburg': 556127,
#  'Orsk': 239800,
#  'Perm': 1013887,
#  'Berezniki': 156466,
#  'Majkop': 144249,
#  'Makhachkala': 576194,
#  'Derbent': 119200,
#  'Kaspijsk': 100129,
#  'Chasavjurt': 131187,
#  "Nazran'": 93335,
#  "Nal'čik": 240203,
#  'Čerkessk': 129069,
#  'Vladikavkaz': 308285,
#  'Grozny': 277414,
#  'Krasnodar': 784048,
#  'Sochi': 368011,
#  'Novorossiysk': 251013,
#  'Armavir': 188832,
#  'Stavropol': 412116,
#  "P'atigorsk": 142511,
#  'Nevinnomyssk': 118360,
#  'Kislovodsk': 128553,
#  'Jessentuki': 100996,
#  'Neftekamsk': 121733,
#  'Kurgan': 325565,
#  'Yekaterinburg': 1396074,
#  'Nizhny Tagil': 358378,
#  "Kamensk-Ural'skij": 174689,
#  "Pervoural'sk": 124528,
#  'Chelyabinsk': 1156201,
#  'Magnitogorsk': 411880,
#  'Zlatoust': 174962,
#  'Miass': 151751,
#  'Kopejsk': 137601,
#  'Gorno Altaysk': 56933,
#  'Barnaul': 629681,
#  'Bijsk': 210115,
#  'Rubcovsk': 147002,
#  'Kemerovo': 540095,
#  'Novokuznetsk': 549182,
#  'Prokopjevsk': 210130,
#  'Novosibirsk': 1523801,
#  'Omsk': 1160670,
#  'Tomsk': 547989,
#  'Seversk': 108590,
#  'Tyumen': 634171,
#  'Ulan-Ude': 416079,
#  'Kyzyl': 109918,
#  'Abakan': 165214,
#  'Krasnoyarsk': 1016385,
#  "Noril'sk": 175365,
#  'Ačinsk': 109155,
#  'Irkutsk': 606137,
#  'Angarsk': 233567,
#  'Bratsk': 246319,
#  'Chita': 331346,
#  'Yakutsk': 286456,
#  'Birobidzhan': 75413,
#  'Anadyr': 13045,
#  'Vladivostok': 600378,
#  'Nachodka': 159719,
#  'Ussurijsk': 158004,
#  'Khabarovsk': 593636,
#  'Komsomolsk-na-Amure': 257891,
#  'Blagoveščensk': 214390,
#  'Petropavlovsk-Kamčatskij': 179780,
#  'Magadan': 95982,
#  'Okhotsk': 4215,
#  'Južno-Sachalinsk': 181728,
#  'Khanty Mansijsk': 80151,
#  'Surgut': 325511,
#  'Nizhnevartovsk': 263228,
#  'Neftejugansk': 122855,
#  'Salekhard': 42544,
#  "Nojabr'sk": 110620,
#  'Novyj Urengoj': 104107,
#  'Bruxelles': 168576,
#  'Schaerbeek': 130587,
#  'Molenbeek-Saint-Jean': 94653,
#  'Anderlecht': 113462,
#  'Antwerpen': 507911,
#  'Gent': 248813,
#  'Charleroi': 203753,
#  'Mons': 93941,
#  'Liège': 195931,
#  'Hasselt': 75579,
#  'Arlon': 28759,
#  'Namur': 110500,
#  'Brugge': 117577,
#  'Leuven': 97692,
#  'Groningen': 198023,
#  'Leeuwarden': 108145,
#  'Enschede': 158494,
#  'Zwolle': 123440,
#  'Lelystad': 76252,
#  'Almere': 196244,
#  'Arnhem': 150989,
#  'Nijmegen': 168810,
#  'Apeldoorn': 157540,
#  'Utrecht': 330081,
#  'Amersfoort': 151270,
#  'Amsterdam': 812895,
#  'Haarlem': 155361,
#  'Zaanstad': 151058,
#  'Hilversum': 86738,
#  'Den Haag': 509623,
#  'Rotterdam': 619180,
#  'Dordrecht': 118780,
#  'Leiden': 121387,
#  "'s-Hertogenbosch": 143822,
#  'Eindhoven': 221279,
#  'Tilburg': 210283,
#  'Breda': 180263,
#  'Maastricht': 122243,
#  'Heerlen': 88139,
#  'Sittard-Geleen': 93726,
#  'Sarajevo': 291422,
#  'Tuzla': 120441,
#  'Zenica': 115134,
#  'Mostar': 113169,
#  'Banja Luka': 199191,
#  'Bijeljina': 114663,
#  'Brčko': 93028,
#  'Arad': 159074,
#  'Piteşti': 155383,
#  'Bacău': 144307,
#  'Oradea': 196367,
#  'Botoşani': 106847,
#  'Brăila': 180302,
#  'Braşov': 253200,
#  'Bucureşti': 1883425,
#  'Buzău': 115494,
#  'Cluj-Napoca': 324576,
#  'Constanţa': 283872,
#  'Craiova': 269506,
#  'Galaţi': 249432,
#  'Iaşi': 290422,
#  'Baia Mare': 123738,
#  'Drobeta-Turnu Severin': 92617,
#  'Târgu Mureş': 134290,
#  'Piatra-Neamţ': 85055,
#  'Ploieşti': 209945,
#  'Satu Mare': 102411,
#  'Sibiu': 147245,
#  'Suceava': 92121,
#  'Timişoara': 319279,
#  'Râmnicu Vâlcea': 98776,
#  'Adana': 1636229,
#  'Adiyaman': 217463,
#  'Afyonkarahisar': 186991,
#  'Agri': 107839,
#  'Aksaray': 186599,
#  'Amasya': 91874,
#  'Ankara': 4630735,
#  'Antalya': 1073794,
#  'Aydin': 195951,
#  'Balikesir': 267903,
#  'Batman': 348963,
#  'Bingol': 98424,
#  'Bolu': 131264,
#  'Bursa': 1734705,
#  'İnegöl': 177617,
#  'Canakkale': 111137,
#  'Corum': 231146,
#  'Denizli': 525497,
#  'Diyarbakir': 892713,
#  'Edirne': 148474,
#  'Elazig': 347857,
#  'Erzincan': 96474,
#  'Erzurum': 384399,
#  'Eskisehir': 659924,
#  'Gaziantep': 1438373,
#  'Giresun': 100712,
#  'Iskenderun': 184833,
#  'Hatay': 216960,
#  'Mersin': 876958,
#  'Tarsus': 245671,
#  'Isparta': 198385,
#  'Istanbul': 13710512,
#  'Izmir': 3401994,
#  'Karaman': 141630,
#  'Kahramanmaraş': 443575,
#  'Kars': 78100,
#  'Kastamonu': 96217,
#  'Kayseri': 1004276,
#  'Kirikkale': 192473,
#  'Luleburgaz': 105279,
#  'Kirsehir': 114244,
#  'Kocaeli': 1527407,
#  'Gebze': 290868,
#  'Konya': 1107886,
#  'Kütahya': 224898,
#  'Malatya': 426381,
#  'Manisa': 309050,
#  'Mardin': 86948,
#  'Kızıltepe': 147585,
#  'Mus': 81764,
#  'Nevsehir': 92068,
#  'Nigde': 118186,
#  'Ordu': 147913,
#  'Rize': 104508,
#  'Sakarya': 590498,
#  'Samsun': 547778,
#  'Şanlıurfa': 526247,
#  'Siirt': 135350,
#  'Sivas': 312587,
#  'Tekirdag': 150112,
#  'Çorlu': 235354,
#  'Tokat': 132437,
#  'Trabzon': 243735,
#  'Usak': 187886,
#  'Van': 370190,
#  'Yozgat': 78328,
#  'Zonguldak': 109080,
#  'Karabük': 110537,
#  'Iğdır': 82656,
#  'Yalova': 102874,
#  'Kilis': 85119,
#  'Duzce': 135557,
#  'Osmaniye': 209255,
#  'Aalborg': 104885,
#  'Århus': 252213,
#  'Randers': 61121,
#  'Vejle': 51804,
#  'Odense': 168798,
#  'Esbjerg': 71579,
#  'København': 549050,
#  'Mariehamn': 10851,
#  'Tampere': 220678,
#  'Lahti': 103396,
#  'Hämeenlinna': 67803,
#  'Kuopio': 106475,
#  'Lappeenranta': 72617,
#  'Kotka': 54714,
#  'Rovaniemi': 61244,
#  'Mikkeli': 54633,
#  'Jyväskylä': 134862,
#  'Joensuu': 74332,
#  'Oulu': 194181,
#  'Pori': 83457,
#  'Turku': 182154,
#  'Helsinki': 614535,
#  'Espoo': 261654,
#  'Vaasa': 66415,
#  'Oslo': 623966,
#  'Sandvika': 116677,
#  'Moss': 24517,
#  'Hamar': 15685,
#  'Lillehammer': 22118,
#  'Drammen': 65473,
#  'Tonsberg': 8984,
#  'Skien': 53015,
#  'Arendal': 12174,
#  'Kristiansand': 84476,
#  'Stavanger': 129191,
#  'Bergen': 267950,
#  'Hermannsverk': 706,
#  'Molde': 21448,
#  'Trondheim': 179692,
#  'Steinkjer': 20480,
#  'Svolvaer': 4500,
#  'Narvik': 18754,
#  'Bodoe': 34479,
#  'Tromsø': 70358,
#  'Hammerfest': 7089,
#  'Vadsoe': 5961,
#  'Göteborg': 526089,
#  'Vanersborg': 35804,
#  'Mariestad': 24255,
#  'Borås': 104867,
#  'Karlskrona': 59007,
#  'Gävle': 96170,
#  'Visby': 20000,
#  'Halmstad': 93231,
#  'Ostersund': 56662,
#  'Jönköping': 129478,
#  'Kalmar': 54554,
#  'Falun': 51900,
#  'Malmö': 307758,
#  'Helsingborg': 132011,
#  'Kristianstad': 80507,
#  'Lund': 112950,
#  'Växjö': 84800,
#  'Lulea': 66526,
#  'Jokkmokk': 6822,
#  'Örebro': 138952,
#  'Linköping': 148521,
#  'Norrköping': 132124,
#  'Nykoping': 64199,
#  'Eskilstuna': 98765,
#  'Stockholm': 881235,
#  'Huddinge': 101010,
#  'Uppsala': 202625,
#  'Karlstad': 86929,
#  'Umeå': 117294,
#  'Harnosand': 27287,
#  'Västerås': 140499,
#  'Aveiro': 53496,
#  'Braga': 114003,
#  'Coimbra': 118016,
#  'Leiria': 50608,
#  'Lisboa': 559248,
#  'Amadora': 89232,
#  'Barreiro': 79042,
#  'Almada': 49578,
#  'Oporto': 266790,
#  'Vila Nova de Gaia': 72576,
#  'Setúbal': 91108,
#  'Ponta Delgada': 46102,
#  'Funchal': 112362,
#  'Newcastle upon Tyne': 268064,
#  'Sunderland': 174286,
#  'Gateshead': 120046,
#  'Middlesbrough': 174700,
#  'Manchester': 109571,
#  'Wigan': 103608,
#  'Stockport': 105878,
#  'Bolton': 194189,
#  'Salford': 103886,
#  'Oldham': 96555,
#  'Rochdale': 107926,
#  'Warrington': 165456,
#  'Blackpool': 147663,
#  'Blackburn': 117963,
#  'Liverpool': 552267,
#  'Birkenhead': 142968,
#  'St Helens': 102885,
#  'Preston': 97886,
#  'Leeds': 474632,
#  'Wakefield': 99251,
#  'Bradford': 349561,
#  'Huddersfield': 162949,
#  'Sheffield': 518090,
#  'Doncaster': 109805,
#  'Rotherham': 109691,
#  'York': 152841,
#  'Kingston upon Hull': 284321,
#  'Nottingham': 289301,
#  'Northampton': 215173,
#  'Leicester': 443760,
#  'Derby': 255394,
#  'Lincoln': 258468,
#  'Birmingham': 212193,
#  'Coventry': 325949,
#  'Wolverhampton': 210319,
#  'Solihull': 123187,
#  'Stoke-on-Trent': 270726,
#  'Worcester': 181041,
#  'Sutton Coldfield': 109015,
#  'Telford': 142723,
#  'Cambridge': 145818,
#  'Peterborough': 161707,
#  'Ipswich': 144957,
#  'Chelmsford': 110507,
#  'Watford': 131982,
#  'Southend-on-Sea': 175547,
#  'Basildon': 107123,
#  'Colchester': 119441,
#  'Norwich': 186682,
#  'Luton': 211228,
#  'London': 366151,
#  'Southampton': 253651,
#  'Portsmouth': 238137,
#  'Basingstoke': 107355,
#  'Milton Keynes': 171750,
#  'High Wycombe': 120256,
#  'Brighton and Hove': 229700,
#  'Maidstone': 107627,
#  'Oxford': 159994,
#  'Reading': 218705,
#  'Slough': 155298,
#  'Eastbourne': 109185,
#  'Gillingham': 104157,
#  'Crawley': 106943,
#  'Worthing': 109120,
#  'Woking': 105367,
#  'Bristol': 535907,
#  'Plymouth': 234982,
#  'Exeter': 113507,
#  'Bournemouth': 187503,
#  'Poole': 154718,
#  'Cheltenham': 116447,
#  'Gloucester': 136362,
#  'Swindon': 182441,
#  'Edinburgh': 459366,
#  'Glasgow': 590507,
#  'Aberdeen': 195021,
#  'Dundee': 147285,
#  'Kirkwall': 6330,
#  'Lerwick': 6570,
#  'Cardiff': 335145,
#  'Swansea': 179485,
#  'Newport': 128060,
#  'Belfast': 280561,
#  'Hefei': 3310268,
#  'Huainan': 1200000,
#  'Bengbu': 449245,
#  'Wuhu': 425740,
#  'Huaibei': 366549,
#  'Maanshan': 305421,
#  'Anqing': 250718,
#  'Tongling': 228017,
#  'Fuyang': 179572,
#  'Luan': 144248,
#  'Chuxian': 125341,
#  'Chaoxian': 123676,
#  'Xuancheng': 112673,
#  'Fuzhou': 3572421,
#  'Xiamen': 3531347,
#  'Nanping': 195064,
#  'Quanzhou': 185154,
#  'Zhangzhou': 181424,
#  'Sanming': 160691,
#  'Longyan': 134481,
#  'Yongan': 111762,
#  'Lanzhou': 2628426,
#  'Tianshui': 244974,
#  'Baiyin': 204970,
#  'Wuwei': 133101,
#  'Yumen': 109234,
#  'Guangzhou': 11071424,
#  'Shantou': 5329024,
#  'Zhanjiang': 400997,
#  'Shenzhen': 10358381,
#  'Shaoguan': 350043,
#  'Chaozhou': 313469,
#  'Dongguan': 8220207,
#  'Foshan': 7194311,
#  'Zhongshan': 3121275,
#  'Jiangmen': 230587,
#  'Yangjiang': 215196,
#  'Zhaoqing': 194784,
#  'Maoming': 178683,
#  'Zhuhai': 164747,
#  'Huizhou': 2344634,
#  'Meixian': 132156,
#  'Heyuan': 120101,
#  'Shanwei': 107847,
#  'Guiyang': 3034750,
#  'Liupanshui': 363954,
#  'Zunyi': 261862,
#  'Anshun': 174142,
#  'Duyun': 132971,
#  'Kaili': 113958,
#  'Haikou': 280153,
#  'Sanya': 102820,
#  'Shijiazhuang': 2834942,
#  'Tangshan': 3372102,
#  'Handan': 1110000,
#  'Zhangjiakou': 529136,
#  'Baoding': 483155,
#  'Qinhuangdao': 364972,
#  'Xingtai': 302789,
#  'Chengde': 246799,
#  'Renqiu': 114256,
#  'Quzhou': 112373,
#  'Hengshui': 104269,
#  'Harbin': 5878939,
#  'Qiqihar': 1380000,
#  'Yichun': 151585,
#  'Jixi': 683885,
#  'Daqing': 657297,
#  'Mudanjiang': 571705,
#  'Hegang': 522747,
#  'Jiamusi': 493409,
#  'Shuangyashan': 386081,
#  'Suihua': 227881,
#  'Shangzhi': 215373,
#  'Qitaihe': 214957,
#  'Beian': 204899,
#  'Acheng': 197595,
#  'Zhaodong': 179976,
#  'Fuling': 173878,
#  'Shuangcheng': 142659,
#  'Anda': 136446,
#  'Mishan': 132744,
#  'Zhengzhou': 4253913,
#  'Luoyang': 1190000,
#  'Kaifeng': 507763,
#  'Xinxiang': 473762,
#  'Anyang': 420332,
#  'Pingdingshan': 410775,
#  'Jiaozuo': 409100,
#  'Nanyang': 243303,
#  'Hebi': 212976,
#  'Xuchang': 208815,
#  'Xinyang': 192509,
#  'Puyang': 175988,
#  'Shangqiu': 164880,
#  'Zhoukou': 146288,
#  'Luohe': 126438,
#  'Zhumadian': 123232,
#  'Sanmenxia': 120523,
#  'Wuhan': 9785388,
#  'Huangshi': 457601,
#  'Xiangfan': 410407,
#  'Yichang': 371601,
#  'Shashi': 281352,
#  'Shiyan': 273786,
#  'Cangzhou': 242708,
#  'Honghu': 190772,
#  'Echeng': 190123,
#  'Tianmen': 186332,
#  'Xiaogan': 166280,
#  'Zaoyang': 162198,
#  ...}

# %%
# Create DataFrame 'cpdf' from dictionary 'provdict'
cpdf = pd.DataFrame(list(provdict.items()), columns=['City', 'Population'])

# %%
#Create a dictionary 'dict'
dict = {}
for city in document.findall("./country/city"):
    # Retreive all the names of the cities, and thier respective population figures
    name = city.find('name')
    pop = city.findall('population')
    if pop:
        # To retrieve the most recent year's population
        dict[name.text] = int(pop[len(pop)-1].text)

# %%
dict
# Out:
# {'Abomey-Calavi': 307745,
#  'Abu Dhabi': 552000,
#  'Aden': 570551,
#  'Akureyri': 17490,
#  'Al Ain': 348000,
#  'Al Fashir': 141884,
#  'Al Fayyum': 316772,
#  'Al Gazira': 211362,
#  'Al Gedaref': 191164,
#  'Al Iskandariyah': 4123869,
#  "Al Isma'iliyah": 300449,
#  'Al Jizah': 2681863,
#  'Al Mahallah al Kubra': 442884,
#  'Al Mansurah': 437311,
#  'Al Manāmah': 143035,
#  'Al Minya': 235234,
#  'Al Qahirah': 8471859,
#  'Al Rayyan': 272860,
#  'Al Sharjah': 519000,
#  'Al Ubayyiḑ': 229425,
#  'Al Uqsur': 451318,
#  'Algiers': 2364230,
#  'Amman': 1812941,
#  'Andorra la Vella': 22256,
#  'Anju': 240117,
#  'Annaba': 342703,
#  'Ansan': 722598,
#  'Antananarivo': 710236,
#  'Antsirabe': 126062,
#  'Antsiranana': 59040,
#  'Anyang': 603184,
#  'Apia': 36735,
#  'Apopa': 143718,
#  'As Seeb': 302992,
#  'As Suways': 510935,
#  'Asmara': 380568,
#  'Asunción': 518792,
#  'Aswan': 265004,
#  'Asyut': 386086,
#  'Auckland': 419418,
#  'Az Zaqaziq': 302611,
#  'Baku': 2150800,
#  'Bandar Seri Begawan': 279924,
#  'Bangkok': 7506700,
#  'Bangui': 622771,
#  'Banha': 158389,
#  'Bani Suwayf': 193535,
#  'Banjul': 357238,
#  'Basseterre': 15500,
#  'Batna': 289504,
#  'Batumi': 121806,
#  'Bayamón': 185996,
#  'Bayrūt': 1100000,
#  'Bejaïa': 176139,
#  'Belize City': 53532,
#  'Belmopan': 13654,
#  'Benghazi': 800000,
#  'Beograd': 1639121,
#  'Bien Hoa': 652646,
#  'Bimbo': 124176,
#  'Biratnagar': 204949,
#  'Bishkek': 901700,
#  'Biskra': 204661,
#  'Blantyre': 661256,
#  'Blida': 331779,
#  'Bo': 149957,
#  'Bobo Dioulasso': 489967,
#  'Bridgetown': 88529,
#  'Bucheon': 847841,
#  'Bujumbura': 497166,
#  'Bulawayo': 653337,
#  'Buon Ma Thuot': 211891,
#  "Bur Sa'id": 570768,
#  'Burgas': 197301,
#  'Busan': 3403135,
#  'Béchar': 165241,
#  'Bălţi': 143300,
#  'Cam Pha': 168196,
#  'Can Tho': 783122,
#  'Cap-Haïtien': 155505,
#  'Carolina': 157832,
#  'Carrefour': 430250,
#  'Castries': 3661,
#  'Cayenne': 57229,
#  'Ceuta': 82376,
#  'Changhua': 236636,
#  'Changwon': 1062731,
#  'Charlotte Amalie': 10354,
#  'Cheongju': 667726,
#  'Chiang Mai': 160200,
#  'Chiayi': 271220,
#  'Chinandega': 133361,
#  'Chitungwiza': 356840,
#  'Chişinău': 663400,
#  'Chon Buri': 233200,
#  'Chongjin': 667929,
#  'Christchurch': 361941,
#  'Chuncheon': 273737,
#  'Cité Soleil': 241055,
#  'Ciudad Delgado': 129965,
#  'Ciudad de Guatemala': 992541,
#  'Ciudad del Este': 222274,
#  'Cobán': 232703,
#  'Colombo': 647100,
#  'Conakry': 1667864,
#  'Constantine': 448028,
#  'Cork': 118912,
#  'Cotonou': 665100,
#  'Cuenca': 331888,
#  'Da Nang': 770911,
#  'Daegu': 2444085,
#  'Daejeon': 1495453,
#  'Damanhur': 241895,
#  'Delmas': 359451,
#  'Dili': 193563,
#  'Djibouti': 475322,
#  'Djougou': 181895,
#  'Doha': 339847,
#  'Dubai': 1171000,
#  'Dublin': 525383,
#  'Dunedin': 123516,
#  'Durrës': 113249,
#  'El Aaiun': 183691,
#  'El Djelfa': 265833,
#  'Elbasan': 78703,
#  'Eldoret': 289380,
#  'Estelí': 122924,
#  'Fakaofo': 490,
#  'Fianarantsoa': 109260,
#  'Fort-de-France': 100000,
#  'Franceville': 103840,
#  'Francistown': 100079,
#  'Freetown': 772873,
#  'Funafuti': 4492,
#  'Gaborone': 227333,
#  'Galway': 75414,
#  'Ganja': 322600,
#  'Gaza': 449477,
#  'Georgetown': 118363,
#  'Ghardaïa': 142913,
#  'Gonaïves': 228725,
#  'Goyang': 897174,
#  'Granada': 123697,
#  'Guayaquil': 2291158,
#  'Gunsan': 256755,
#  'Gustavia': 2299,
#  'Gwangju': 1469293,
#  'Ha Long': 201990,
#  'Haeju': 273300,
#  'Hafnarfjordur': 26099,
#  'Haiphong': 846191,
#  'Hamhung-Hungnam': 768551,
#  'Hamilton': 132060,
#  'Hanoi': 2644536,
#  'Harare': 1485231,
#  'Hebron': 163146,
#  'Herat': 335200,
#  'Ho Chi Minh': 5968384,
#  'Hong Kong': 7055071,
#  'Honiara': 49107,
#  'Hsinchu': 425071,
#  'Hualien': 108077,
#  'Hue': 302983,
#  'Huichon': 168180,
#  'Incheon': 2637652,
#  'Irbid': 250645,
#  'Jeju': 399416,
#  'Jeonju': 643079,
#  'Jhongli': 376217,
#  'Jinju': 337230,
#  'Jinotega': 123548,
#  'Juba': 372410,
#  'Kabul': 2435400,
#  'Kaechon': 319554,
#  'Kaesong': 308440,
#  'Kafr ad Dawwar': 262748,
#  'Kampala': 1516210,
#  'Kandahar': 311800,
#  'Kanggye': 251971,
#  'Kaohsiung': 2778659,
#  'Kassala': 234622,
#  'Kathmandu': 1003285,
#  'Kaunas': 307498,
#  'Keelung': 377153,
#  'Keflavik': 13862,
#  'Khartoum': 947483,
#  'Khartoum North': 700887,
#  'Khon Kaen': 223300,
#  'Kigali': 603049,
#  'Kim Chaek': 207299,
#  'Kingston': 662426,
#  'Kingstown': 12909,
#  'Kisumu': 388311,
#  'Klaipeda': 158891,
#  'Kolonia': 5681,
#  'Koror': 11665,
#  'Korçë': 51152,
#  'Kumanovo': 107745,
#  'Kusong': 196515,
#  'Kutaisi': 185965,
#  'Kuwait': 637411,
#  'Laghouat': 134372,
#  'Lalitpur': 226728,
#  'Larnaka': 51468,
#  'Lefkosia': 55014,
#  'Lemesos': 101000,
#  'León': 201100,
#  'Libreville': 538195,
#  'Lilongwe': 674448,
#  'Limerick': 56779,
#  'Ljubljana': 282994,
#  'Lomé': 839566,
#  'Long Xuyen': 245699,
#  'Luxembourg': 99852,
#  'Machakos': 150041,
#  'Majunga': 106780,
#  'Majuro': 27797,
#  'Male': 133019,
#  'Malindi': 118265,
#  'Managua': 1028808,
#  'Maribor': 111374,
#  'Marigot': 5700,
#  'Masaya': 166588,
#  'Maseru': 227880,
#  'Matagalpa': 150643,
#  'Mazar-i-Sharif': 288700,
#  'Mbabane': 57992,
#  'Mbarara': 195013,
#  'Mejicanos': 157188,
#  'Melekeok': 391,
#  'Melilla': 78476,
#  'Misratah': 360000,
#  'Mixco': 483705,
#  'Mokpo': 244543,
#  'Mombasa': 938131,
#  'Monaco': 975,
#  'Monrovia': 1010970,
#  'Montevideo': 1318755,
#  'Moroni': 41557,
#  'Mostaganem': 162885,
#  'Mukono': 161996,
#  'Muscat': 27216,
#  "N'Djamena": 951418,
#  "N'Zérékoré": 194178,
#  'Nablus': 126132,
#  'Nairobi': 3133518,
#  'Nakhon Ratchasima': 254900,
#  'Nakhon Sawan': 142500,
#  'Nakhon Si Thammarat': 167400,
#  'Nakuru': 307990,
#  'Nam Dinh': 193768,
#  'Nampho': 366815,
#  'Nassau': 248948,
#  'New Taipei': 3939305,
#  'Nha Trang': 292693,
#  'Niš': 257867,
#  'Nonthaburi': 481900,
#  'Novi Sad': 335701,
#  'Nukualofa': 23658,
#  'Nyala': 227183,
#  'Omdurman': 1271403,
#  'Oran': 803329,
#  'Osh': 265200,
#  'Osijek': 83496,
#  'Ouagadougou': 1475223,
#  'Palikir': 6444,
#  'Paramaribo': 240924,
#  'Philipsburg': 1338,
#  'Phnom Penh': 703963,
#  'Phuket': 75573,
#  'Pingtung': 207862,
#  'Plovdiv': 331796,
#  'Plymouth': 0,
#  'Podgorica': 150977,
#  'Pokhara': 264991,
#  'Ponce': 132502,
#  'Port Moresby': 318128,
#  'Port Sudan': 308195,
#  'Port Vila': 44040,
#  'Port-Gentil': 105712,
#  'Port-au-Prince': 875978,
#  'Port-of-Spain': 548299,
#  'Porto-Novo': 223552,
#  'Praia': 131719,
#  'Prishtine': 198214,
#  'Pyongyang': 3255288,
#  'Pétion-Ville': 271175,
#  'Qina': 206831,
#  'Qui Nhon': 255463,
#  'Quito': 1619146,
#  'Rach Gia': 210784,
#  'Reykjavik': 118061,
#  'Rijeka': 127498,
#  'Roseau': 14725,
#  'Ruse': 146609,
#  'Rīga': 696618,
#  "Saint George's": 37000,
#  'Saint Johns': 22219,
#  'Saint-Denis': 145347,
#  'Saint-Pierre': 5618,
#  'Salto': 104011,
#  'Samut Prakan': 277600,
#  'San Juan': 381931,
#  'San Marino': 4227,
#  'San Miguel': 218410,
#  'San Salvador': 354174,
#  "Sana'a": 1527861,
#  'Santa Ana': 245421,
#  'Santa Tecla': 126353,
#  'Santiago': 591985,
#  'Santo Domingo': 2749703,
#  'Santo Domingo de los Colorados': 305632,
#  'Saraburi': 125300,
#  'Sariwon': 307764,
#  'Seongnam': 951424,
#  'Seoul': 9708483,
#  'Sfax': 299235,
#  'Shibin al Kum': 177060,
#  'Shkodër': 77075,
#  'Shubra al Khimah': 1016722,
#  'Sidi Bel Abbës': 210146,
#  'Singapore': 5076700,
#  'Sinpho': 152759,
#  'Sinuiju': 359341,
#  'Skikda': 182903,
#  'Skopje': 514967,
#  'Sofia': 1270284,
#  'Sokhumi': 62914,
#  'Songkhla': 294200,
#  'Sousse': 223844,
#  'Soyapango': 268228,
#  'Split': 165893,
#  'Sri Jayawardhanapura Kotte': 116366,
#  'Stara Zagora': 136363,
#  'Suhaj': 189638,
#  'Sumgayit': 290500,
#  'Sunchon': 297317,
#  'Suva': 75225,
#  'Suwon': 1064951,
#  'São Tomé': 49957,
#  'Sétif': 252127,
#  "Ta'izz": 458933,
#  'Taichung': 2684893,
#  'Tainan': 1881645,
#  'Taipei': 2673226,
#  'Taitung': 107720,
#  'Tallinn': 399340,
#  'Tamanrasset': 92635,
#  'Tamatave': 137782,
#  'Tanchon': 345875,
#  'Tanta': 421076,
#  'Taoyuan': 413488,
#  'Tarawa': 50182,
#  'Tartu': 103284,
#  'Tbilisi': 1073345,
#  'Thai Nguyen': 199732,
#  'Thimphu': 42465,
#  'Tipitapa': 130627,
#  'Tirana': 418495,
#  'Tiraspol': 148917,
#  'Tlemcen': 173531,
#  'Tokchon': 237133,
#  'Toliara': 80826,
#  'Tougourt': 143270,
#  'Tripoli': 1500000,
#  'Tunis': 651284,
#  'Tébessa': 194461,
#  'Tórshavn': 12245,
#  'Ubon Ratchathani': 149700,
#  'Ulaanbaatar': 760077,
#  'Ulsan': 1081985,
#  'Vaduz': 5241,
#  'Valletta': 5748,
#  'Varna': 330486,
#  'Vatican City': 842,
#  'Victoria': 24970,
#  'Vientiane': 698318,
#  'Villa Nueva': 527174,
#  'Vilnius': 538747,
#  'Vinh': 215577,
#  'Vlorë': 79513,
#  'Vung Tau': 282415,
#  'Wellington': 185187,
#  'Willemstad': 125000,
#  'Windhoek': 322500,
#  'Wonsan': 363127,
#  'Yeosu': 267921,
#  'Yerevan': 1066264,
#  'Yongin': 852505,
#  'Zadar': 70674,
#  'Zagreb': 686568,
#  'Zarqa': 395227,
#  'al Hudaydah': 402560}

# %%
cpdf1 = pd.DataFrame(list(dict.items()), columns=['City', 'Population'])

# %%
cpdf.append(cpdf1)
# Out:
#                  City  Population
# 0              Kavala       58790
# 1              Athina      664046
# 2            Peiraias      163688
# 3           Peristeri      139981
# 4            Acharnes      106943
# 5               Patra      213984
# 6             Kerkyra      102071
# 7            Ioannina      112486
# 8        Thessaloniki      325182
# 9             Iraklio      173993
# 10             Chania      108642
# 11             Rhodes      115490
# 12              Lamia       75315
# 13           Chalkida      102223
# 14            Larissa      162591
# 15              Volos      144449
# 16             Karyes         233
# 17         Strasbourg      272222
# 18           Mulhouse      110351
# 19           Bordeaux      239399
# 20   Clermont-Ferrand      140957
# 21               Caen      108793
# 22             Rennes      208033
# 23              Brest      309764
# 24              Dijon      151672
# 25            Orléans      114185
# 26              Tours      134633
# 27              Reims      180752
# 28            Ajaccio       66245
# 29           Besançon      115879
# ..                ...         ...
# 363        N'Zérékoré      194178
# 364          Monrovia     1010970
# 365          Djibouti      475322
# 366            Asmara      380568
# 367           Mombasa      938131
# 368           Malindi      118265
# 369          Machakos      150041
# 370           Nairobi     3133518
# 371            Kisumu      388311
# 372            Nakuru      307990
# 373           Eldoret      289380
# 374            Banjul      357238
# 375          Freetown      772873
# 376                Bo      149957
# 377           Kampala     1516210
# 378           Mbarara      195013
# 379            Mukono      161996
# 380            Maseru      227880
# 381       Antsiranana       59040
# 382      Antananarivo      710236
# 383         Antsirabe      126062
# 384      Fianarantsoa      109260
# 385           Majunga      106780
# 386          Tamatave      137782
# 387           Toliara       80826
# 388          Lilongwe      674448
# 389          Blantyre      661256
# 390           Mbabane       57992
# 391       Saint-Denis      145347
# 392          São Tomé       49957
#
# [3010 rows x 2 columns]

# %%
cpdf.sort_values('Population', ascending=False).head(10)
# Out:
#            City  Population
# 1189   Shanghai    22315474
# 673    Istanbul    13710512
# 1350     Mumbai    12442373
# 421      Moskva    11979529
# 1188    Beijing    11716620
# 2269  São Paulo    11152344
# 1190    Tianjin    11090314
# 915   Guangzhou    11071424
# 1396      Delhi    11034555
# 918    Shenzhen    10358381

# %% [markdown]
# # 3. 10 ethnic groups with the largest overall populations (sum of best/latest estimates over all countries)

# %%
c_p = {}
for e in document.iter('country'):
    cntry = e.find('name')
    pop = e.find('.//population[last()]')
    if cntry != None:
        if pop != None:
            c_p[cntry.text] = int(pop.text)

# %%
c_p
# Out:
# {'Afghanistan': 26023100,
#  'Albania': 2800138,
#  'Algeria': 37062820,
#  'American Samoa': 55519,
#  'Andorra': 78115,
#  'Angola': 24383301,
#  'Anguilla': 13037,
#  'Antigua and Barbuda': 81799,
#  'Argentina': 42669500,
#  'Armenia': 3026879,
#  'Aruba': 101484,
#  'Australia': 23135281,
#  'Austria': 8499759,
#  'Azerbaijan': 9356500,
#  'Bahamas': 353658,
#  'Bahrain': 1234596,
#  'Bangladesh': 149772364,
#  'Barbados': 277821,
#  'Belarus': 9460692,
#  'Belgium': 11099554,
#  'Belize': 312971,
#  'Benin': 9983884,
#  'Bermuda': 64237,
#  'Bhutan': 733004,
#  'Bolivia': 10027262,
#  'Bosnia and Herzegovina': 3791622,
#  'Botswana': 2038228,
#  'Brazil': 202768562,
#  'British Virgin Islands': 23161,
#  'Brunei': 393372,
#  'Bulgaria': 7284552,
#  'Burkina Faso': 17322796,
#  'Burundi': 8444784,
#  'Cambodia': 14364931,
#  'Cameroon': 19406100,
#  'Canada': 35158304,
#  'Cape Verde': 491875,
#  'Cayman Islands': 55691,
#  'Central African Republic': 4349921,
#  'Ceuta': 82376,
#  'Chad': 11720781,
#  'Chile': 16341929,
#  'China': 1360720000,
#  'Christmas Island': 2072,
#  'Cocos Islands': 596,
#  'Colombia': 47661787,
#  'Comoros': 683081,
#  'Congo': 4001831,
#  'Cook Islands': 17794,
#  'Costa Rica': 4773119,
#  'Cote dIvoire': 22671331,
#  'Croatia': 4290612,
#  'Cuba': 11167325,
#  'Curacao': 150563,
#  'Cyprus': 840407,
#  'Czech Republic': 10562214,
#  'Denmark': 5580516,
#  'Djibouti': 834036,
#  'Dominica': 70739,
#  'Dominican Republic': 9445281,
#  'Ecuador': 14483499,
#  'Egypt': 83667047,
#  'El Salvador': 6290420,
#  'Equatorial Guinea': 696167,
#  'Eritrea': 5741159,
#  'Estonia': 1294455,
#  'Ethiopia': 84320987,
#  'Falkland Islands': 2931,
#  'Faroe Islands': 48197,
#  'Fiji': 860559,
#  'Finland': 5455068,
#  'France': 64933400,
#  'French Guiana': 237549,
#  'French Polynesia': 268270,
#  'Gabon': 1556222,
#  'Gambia': 1882450,
#  'Gaza Strip': 1760037,
#  'Georgia': 4483800,
#  'Germany': 80219695,
#  'Ghana': 24658823,
#  'Gibraltar': 27495,
#  'Greece': 10816286,
#  'Greenland': 56370,
#  'Grenada': 103328,
#  'Guadeloupe': 404635,
#  'Guam': 159358,
#  'Guatemala': 15073375,
#  'Guernsey': 59807,
#  'Guinea': 10628972,
#  'Guinea-Bissau': 1586624,
#  'Guyana': 747884,
#  'Haiti': 9896400,
#  'Holy See': 842,
#  'Honduras': 8045990,
#  'Hong Kong': 7071576,
#  'Hungary': 9937628,
#  'Iceland': 318452,
#  'India': 1210854977,
#  'Indonesia': 252124458,
#  'Iran': 75149669,
#  'Iraq': 33330512,
#  'Ireland': 4588252,
#  'Isle of Man': 84497,
#  'Israel': 7420368,
#  'Italy': 59433744,
#  'Jamaica': 2697983,
#  'Japan': 127298000,
#  'Jersey': 97857,
#  'Jordan': 6249000,
#  'Kazakhstan': 17165239,
#  'Kenya': 40909194,
#  'Kiribati': 103058,
#  'Kosovo': 1733872,
#  'Kuwait': 2991580,
#  'Kyrgyzstan': 5776600,
#  'Laos': 6514432,
#  'Latvia': 2201196,
#  'Lebanon': 4341092,
#  'Lesotho': 2008921,
#  'Liberia': 3957990,
#  'Libya': 6040612,
#  'Liechtenstein': 36636,
#  'Lithuania': 2979310,
#  'Luxembourg': 524853,
#  'Macao': 552503,
#  'Macedonia': 2059794,
#  'Madagascar': 21842167,
#  'Malawi': 15013694,
#  'Malaysia': 27565821,
#  'Maldives': 341256,
#  'Mali': 13985961,
#  'Malta': 417432,
#  'Marshall Islands': 53158,
#  'Martinique': 392291,
#  'Mauritania': 3537368,
#  'Mauritius': 1237091,
#  'Mayotte': 212645,
#  'Melilla': 78476,
#  'Mexico': 112336538,
#  'Micronesia': 102843,
#  'Moldova': 3559541,
#  'Monaco': 36845,
#  'Mongolia': 2754685,
#  'Montenegro': 620029,
#  'Montserrat': 4922,
#  'Morocco': 32901622,
#  'Mozambique': 23700715,
#  'Myanmar': 51419420,
#  'Namibia': 2113077,
#  'Nauru': 10025,
#  'Nepal': 26494504,
#  'Netherlands': 16843181,
#  'New Caledonia': 245580,
#  'New Zealand': 4242048,
#  'Nicaragua': 6071045,
#  'Niger': 17138707,
#  'Nigeria': 164294516,
#  'Niue': 1611,
#  'Norfolk Island': 2169,
#  'North Korea': 24500520,
#  'Northern Mariana Islands': 53883,
#  'Norway': 5051275,
#  'Oman': 3623001,
#  'Pakistan': 173149306,
#  'Palau': 17501,
#  'Panama': 3405813,
#  'Papua New Guinea': 7275324,
#  'Paraguay': 6672631,
#  'Peru': 30135875,
#  'Philippines': 92337852,
#  'Pitcairn': 66,
#  'Poland': 38533789,
#  'Portugal': 10561614,
#  'Puerto Rico': 3725789,
#  'Qatar': 1699435,
#  'Reunion': 828581,
#  'Romania': 20121641,
#  'Russia': 143666931,
#  'Rwanda': 10515973,
#  'Saint Barthelemy': 9072,
#  'Saint Helena': 5663,
#  'Saint Kitts and Nevis': 52352,
#  'Saint Lucia': 165595,
#  'Saint Martin': 37630,
#  'Saint Pierre and Miquelon': 6312,
#  'Saint Vincent and the Grenadines': 109991,
#  'Samoa': 187820,
#  'San Marino': 32440,
#  'Sao Tome and Principe': 187356,
#  'Saudi Arabia': 27136977,
#  'Senegal': 13508715,
#  'Serbia': 7120666,
#  'Seychelles': 90945,
#  'Sierra Leone': 5751976,
#  'Singapore': 5076700,
#  'Sint Maarten': 37429,
#  'Slovakia': 5397036,
#  'Slovenia': 2058821,
#  'Solomon Islands': 526447,
#  'Somalia': 9636173,
#  'South Africa': 51770560,
#  'South Korea': 51141463,
#  'South Sudan': 8260490,
#  'Spain': 46815916,
#  'Sri Lanka': 20263723,
#  'Sudan': 35652002,
#  'Suriname': 541638,
#  'Svalbard': 1872,
#  'Swaziland': 1193148,
#  'Sweden': 9555893,
#  'Switzerland': 8139631,
#  'Syria': 20866000,
#  'Taiwan': 23315822,
#  'Tajikistan': 8161100,
#  'Tanzania': 44928923,
#  'Thailand': 65981659,
#  'Timor-Leste': 1066582,
#  'Togo': 6191155,
#  'Tokelau': 1383,
#  'Tonga': 103252,
#  'Trinidad and Tobago': 1328019,
#  'Tunisia': 10982754,
#  'Turkey': 75627384,
#  'Turkmenistan': 5041995,
#  'Turks and Caicos Islands': 31458,
#  'Tuvalu': 9827,
#  'Uganda': 34856813,
#  'Ukraine': 45633637,
#  'United Arab Emirates': 8441537,
#  'United Kingdom': 64105654,
#  'United States': 318857056,
#  'Uruguay': 3286314,
#  'Uzbekistan': 27769270,
#  'Vanuatu': 236299,
#  'Venezuela': 28946101,
#  'Vietnam': 88772900,
#  'Virgin Islands': 106405,
#  'Wallis and Futuna': 12197,
#  'West Bank': 2790331,
#  'Western Sahara': 554795,
#  'Yemen': 24527000,
#  'Zaire': 62191161,
#  'Zambia': 13046508,
#  'Zimbabwe': 13061239}

# %%
co_etg = []
for el in document.iterfind('country'):
    co = el.find('name').text
    for et in el.iterfind('ethnicgroup'):
        etg_name = et.text
        etg_prcnt = et.attrib['percentage']

# %%
co_etg.append([co,etg_name,etg_prcnt])

# %%
co_etg
# Out:
# [['Seychelles', 'Seychellois', '100']]

# %%
c.append(cols)
c

# %%
labels = ['Country', 'Population', 'Ethnic_Group']
eg_df = pd.DataFrame.from_records(c, columns=labels)
eg_df
#city_df.sort_values('Population', ascending=False).head(10)

# %%
for po in popl:
        p = po.find('.//population[last()]')
        if p != None:
                p = int(population.text)
        for et in etg:
            eg = et.find('.//ethnicgroup[1]')
            #if eg != None:
                #eg = eg.text            
                #df = ldf.append(cntry, eg, p)
                #df = pd.DataFrame

# %% [markdown]
# # 4. Name and Country of a) longest river, b) largest lake and c) airport at highest elevation

# %%
cit_pop_list = []

#start a loop to go through all the countries in the XML
for element in document.iterfind('country'):
    ctry = element.find('name').text
    '''
    Countries may or may not have provinces, and there are some countries where the city name is not unique. e.g.
    Richmond in United States. So the only way to uniquely identify a city to show the city along with the country
    and the province.
    
    we store the provice names of a country in a dictionary here. This dictionary will be used to fill in the 
    province names. Storing the provinces here reduces the amount of code required.   
    '''
  
    prov_dict = {}
    for province in element.findall('province'):
        prov_dict[province.attrib['id']] = province.find('name').text
        
    # setup a loop for all the cities within a country    
    for subelement in element.getiterator('city'):
        city = subelement.find('name')
        if city != None: # check to see if 'city' element is present
            # for each city there may be more than one population entry, the below code stores only the latest
            # population entry, i.e. entry whose year value is max
            yr = 0
            pop = 0
            #get the population elements for each city
            for popelement in subelement.getiterator('population'):
                if popelement != None: # check to see if any 'population' element is present
                    #store the population for the year that is the greatest for this particular city
                    if int(popelement.attrib['year']) > yr:
                        yr = int(popelement.attrib['year'])
                        pop = int(popelement.text)
                        #if this city has provinces, store the province name from the dict values created
                        #earlier in the program
                        if 'province' in subelement.attrib:
                            prov = prov_dict[subelement.attrib['province']]
                        else:
                            prov = 'No Province'
            #create a list with the elements and append to the list
            cit_pop_list.append([ctry,city.text,prov,int(popelement.attrib['year']),int(popelement.text)])
        
#once the list is constructed, create a DataFrame from the list
#cit_pop_df=pd.DataFrame.from_records(cit_pop_list)

#set the column names
#cit_pop_df.columns=['Country','City','Province','Year','Population']


#cit_pop_df.head(10)

# %%
cit_pop_list
# Out:
# [['Albania', 'Tirana', 'No Province', 2011, 418495],
#  ['Albania', 'Shkodër', 'No Province', 2011, 77075],
#  ['Albania', 'Durrës', 'No Province', 2011, 113249],
#  ['Albania', 'Vlorë', 'No Province', 2011, 79513],
#  ['Albania', 'Elbasan', 'No Province', 2011, 78703],
#  ['Albania', 'Korçë', 'No Province', 2011, 51152],
#  ['Greece', 'Komotini', 'No Province', 2011, 51152],
#  ['Greece', 'Kavala', 'Anatolikis Makedonias kai Thrakis', 2011, 58790],
#  ['Greece', 'Athina', 'Attikis', 2011, 664046],
#  ['Greece', 'Peiraias', 'Attikis', 2011, 163688],
#  ['Greece', 'Peristeri', 'Attikis', 2011, 139981],
#  ['Greece', 'Acharnes', 'Attikis', 2011, 106943],
#  ['Greece', 'Patra', 'Dytikis Elladas', 2011, 213984],
#  ['Greece', 'Kozani', 'Dytikis Elladas', 2011, 213984],
#  ['Greece', 'Kerkyra', 'Ionion Nison', 2011, 102071],
#  ['Greece', 'Ioannina', 'Ipeiroy', 2011, 112486],
#  ['Greece', 'Thessaloniki', 'Kentrikis Makedonias', 2011, 325182],
#  ['Greece', 'Iraklio', 'Kritis', 2011, 173993],
#  ['Greece', 'Chania', 'Kritis', 2011, 108642],
#  ['Greece', 'Ermoupoli', 'Kritis', 2011, 108642],
#  ['Greece', 'Rhodes', 'Notioy Aigaioy', 2011, 115490],
#  ['Greece', 'Tripoli', 'Notioy Aigaioy', 2011, 115490],
#  ['Greece', 'Lamia', 'Stereas Elladas', 2011, 75315],
#  ['Greece', 'Chalkida', 'Stereas Elladas', 2011, 102223],
#  ['Greece', 'Larissa', 'Thessalias', 2011, 162591],
#  ['Greece', 'Volos', 'Thessalias', 2011, 144449],
#  ['Greece', 'Mytilini', 'Thessalias', 2011, 144449],
#  ['Greece', 'Karyes', 'Aghion Oros', 2014, 233],
#  ['Macedonia', 'Skopje', 'No Province', 2011, 514967],
#  ['Macedonia', 'Kumanovo', 'No Province', 2011, 107745],
#  ['Serbia', 'Beograd', 'No Province', 2011, 1639121],
#  ['Serbia', 'Novi Sad', 'No Province', 2011, 335701],
#  ['Serbia', 'Niš', 'No Province', 2011, 257867],
#  ['Montenegro', 'Podgorica', 'No Province', 2011, 150977],
#  ['Kosovo', 'Prishtine', 'No Province', 2011, 198214],
#  ['Andorra', 'Andorra la Vella', 'No Province', 2011, 22256],
#  ['France', 'Strasbourg', 'Alsace', 2011, 272222],
#  ['France', 'Mulhouse', 'Alsace', 2011, 110351],
#  ['France', 'Bordeaux', 'Aquitaine', 2011, 239399],
#  ['France', 'Clermont-Ferrand', 'Auvergne', 2011, 140957],
#  ['France', 'Caen', 'Basse Normandie', 2011, 108793],
#  ['France', 'Rennes', 'Bretagne', 2011, 208033],
#  ['France', 'Brest', 'Bretagne', 2011, 140547],
#  ['France', 'Dijon', 'Bourgogne', 2011, 151672],
#  ['France', 'Orléans', 'Centre', 2011, 114185],
#  ['France', 'Tours', 'Centre', 2011, 134633],
#  ['France', 'Reims', 'Champagne-Ardenne', 2011, 180752],
#  ['France', 'Chalons en Champagne', 'Champagne-Ardenne', 2011, 180752],
#  ['France', 'Ajaccio', 'Corse', 2011, 66245],
#  ['France', 'Besançon', 'Franche-Comté', 2011, 115879],
#  ['France', 'Rouen', 'Haute-Normandie', 2011, 111553],
#  ['France', 'Le Havre', 'Haute-Normandie', 2011, 174156],
#  ['France', 'Paris', 'Île-de-France', 2011, 2249975],
#  ['France', 'Boulogne-Billancourt', 'Île-de-France', 2011, 116220],
#  ['France', 'Argenteuil', 'Île-de-France', 2011, 104282],
#  ['France', 'Montreuil', 'Île-de-France', 2011, 103068],
#  ['France', 'Saint-Paul', 'Île-de-France', 2011, 103916],
#  ['France', 'Montpellier', 'Languedoc-Roussillon', 2011, 264538],
#  ['France', 'Nîmes', 'Languedoc-Roussillon', 2011, 144940],
#  ['France', 'Perpignan', 'Languedoc-Roussillon', 2011, 118238],
#  ['France', 'Limoges', 'Limousin', 2011, 137758],
#  ['France', 'Metz', 'Lorraine', 2011, 119962],
#  ['France', 'Nancy', 'Lorraine', 2011, 105382],
#  ['France', 'Toulouse', 'Midi-Pyrénées', 2011, 447340],
#  ['France', 'Lille', 'Nord-Pas-de-Calais', 2011, 227533],
#  ['France', 'Nantes', 'Pays de la Loire', 2011, 287845],
#  ['France', 'Angers', 'Pays de la Loire', 2011, 148803],
#  ['France', 'Le Mans', 'Pays de la Loire', 2011, 143240],
#  ['France', 'Amiens', 'Picardie', 2011, 133327],
#  ['France', 'Poitiers', 'Poitou Charentes', 2011, 87646],
#  ['France', 'Marseille', "Provence-Alpes-Côte d'Azur", 2011, 850636],
#  ['France', 'Nice', "Provence-Alpes-Côte d'Azur", 2011, 344064],
#  ['France', 'Toulon', "Provence-Alpes-Côte d'Azur", 2011, 163974],
#  ['France', 'Aix-en-Provence', "Provence-Alpes-Côte d'Azur", 2011, 140684],
#  ['France', 'Lyon', 'Rhône-Alpes', 2011, 491268],
#  ['France', 'Grenoble', 'Rhône-Alpes', 2011, 157424],
#  ['France', 'Saint-Étienne', 'Rhône-Alpes', 2011, 170049],
#  ['France', 'Villeurbanne', 'Rhône-Alpes', 2011, 145034],
#  ['Spain', 'Sevilla', 'Andalucía', 2011, 698042],
#  ['Spain', 'Almería', 'Andalucía', 2011, 189680],
#  ['Spain', 'Cádiz', 'Andalucía', 2011, 124014],
#  ['Spain', 'Córdoba', 'Andalucía', 2011, 328326],
#  ['Spain', 'Granada', 'Andalucía', 2011, 241003],
#  ['Spain', 'Huelva', 'Andalucía', 2011, 147808],
#  ['Spain', 'Málaga', 'Andalucía', 2011, 561435],
#  ['Spain', 'Jerez de la Frontera', 'Andalucía', 2011, 211784],
#  ['Spain', 'Jaén', 'Andalucía', 2011, 116469],
#  ['Spain', 'Algeciras', 'Andalucía', 2011, 117695],
#  ['Spain', 'Marbella', 'Andalucía', 2011, 135124],
#  ['Spain', 'Dos Hermanas', 'Andalucía', 2011, 128433],
#  ['Spain', 'Zaragoza', 'Aragón', 2011, 678115],
#  ['Spain', 'Oviedo', 'Asturias', 2011, 225005],
#  ['Spain', 'Gijón', 'Asturias', 2011, 276969],
#  ['Spain', 'Palma de Mallorca', 'Illes Balears', 2011, 402044],
#  ['Spain', 'Vitoria-Gasteiz', 'País Vasco', 2011, 240753],
#  ['Spain', 'Bilbao', 'País Vasco', 2011, 351356],
#  ['Spain', 'Barakaldo', 'País Vasco', 2011, 100064],
#  ['Spain', 'Donostia', 'País Vasco', 2011, 185512],
#  ['Spain', 'Santa Cruz de Tenerife', 'Canarias', 2011, 204476],
#  ['Spain', 'San Cristóbal de La Laguna', 'Canarias', 2011, 152025],
#  ['Spain', 'Las Palmas de Gran Canaria', 'Canarias', 2011, 381271],
#  ['Spain', 'Telde', 'Canarias', 2011, 101080],
#  ['Spain', 'Santander', 'Cantabria', 2011, 178095],
#  ['Spain', 'Valladolid', 'Castilla y León', 2011, 311682],
#  ['Spain', 'Burgos', 'Castilla y León', 2011, 178864],
#  ['Spain', 'León', 'Castilla y León', 2011, 131411],
#  ['Spain', 'Salamanca', 'Castilla y León', 2011, 151658],
#  ['Spain', 'Toledo', 'Castilla y León', 2011, 151658],
#  ['Spain', 'Albacete', 'Castilla-La Mancha', 2011, 171999],
#  ['Spain', 'Barcelona', 'Cataluña', 2011, 1611013],
#  ['Spain', 'Lleida', 'Cataluña', 2011, 137283],
#  ['Spain', 'Tarragona', 'Cataluña', 2011, 133223],
#  ['Spain', 'Reus', 'Cataluña', 2011, 106849],
#  ['Spain', 'Hospitalet de Llobregat', 'Cataluña', 2011, 256509],
#  ['Spain', 'Badalona', 'Cataluña', 2011, 219241],
#  ['Spain', 'Sabadell', 'Cataluña', 2011, 206949],
#  ['Spain', 'Terrassa', 'Cataluña', 2011, 214406],
#  ['Spain', 'Santa Coloma de Gramenet', 'Cataluña', 2011, 119391],
#  ['Spain', 'Mataró', 'Cataluña', 2011, 123367],
#  ['Spain', 'Badajoz', 'Extremadura', 2011, 151214],
#  ['Spain', 'Merida', 'Extremadura', 2011, 151214],
#  ['Spain', 'A Coruña', 'Galicia', 2011, 245053],
#  ['Spain', 'Vigo', 'Galicia', 2011, 295623],
#  ['Spain', 'Ourense', 'Galicia', 2011, 107314],
#  ['Spain', 'Santiago de Compostela', 'Galicia', 2011, 107314],
#  ['Spain', 'Madrid', 'Madrid', 2011, 3198645],
#  ['Spain', 'Móstoles', 'Madrid', 2011, 203493],
#  ['Spain', 'Leganés', 'Madrid', 2011, 185758],
#  ['Spain', 'Alcalá de Henares', 'Madrid', 2011, 200505],
#  ['Spain', 'Fuenlabrada', 'Madrid', 2011, 196986],
#  ['Spain', 'Getafe', 'Madrid', 2011, 168642],
#  ['Spain', 'Alcorcón', 'Madrid', 2011, 167217],
#  ['Spain', 'Torrejón de Ardoz', 'Madrid', 2011, 123213],
#  ['Spain', 'Parla', 'Madrid', 2011, 122045],
#  ['Spain', 'Alcobendas', 'Madrid', 2011, 110351],
#  ['Spain', 'Murcia', 'Murcia', 2011, 437667],
#  ['Spain', 'Cartagena', 'Murcia', 2011, 215757],
#  ['Spain', 'Pamplona', 'Navarra', 2011, 195943],
#  ['Spain', 'Logroño', 'La Rioja', 2011, 152698],
#  ['Spain', 'Valencia', 'Valenciana', 2011, 792054],
#  ['Spain', 'Alicante', 'Valenciana', 2011, 329325],
#  ['Spain', 'Elche', 'Valenciana', 2011, 227417],
#  ['Spain', 'Castellón de la Plana', 'Valenciana', 2011, 176298],
#  ['Austria', 'Eisenstadt', 'Burgenland', 2013, 13485],
#  ['Austria', 'Klagenfurt', 'Kärnten', 2013, 96531],
#  ['Austria', 'Villach', 'Kärnten', 2013, 59942],
#  ['Austria', 'Bregenz', 'Kärnten', 2013, 59942],
#  ['Austria', 'Wien', 'Wien', 2013, 1761738],
#  ['Austria', 'Linz', 'Oberösterreich', 2013, 193511],
#  ['Austria', 'Wels', 'Oberösterreich', 2013, 59239],
#  ['Austria', 'Innsbruck', 'Tirol', 2013, 124386],
#  ['Austria', 'Graz', 'Steiermark', 2013, 269211],
#  ['Austria', 'Salzburg', 'Salzburg', 2013, 146676],
#  ['Austria', 'St. Pölten', 'Niederösterreich', 2013, 52100],
#  ['Czech Republic', 'Praha', 'Praha', 2011, 1289556],
#  ['Czech Republic', 'České Budějovice', 'Jihočeský', 2011, 95589],
#  ['Czech Republic', 'Brno', 'Jihomoravský', 2011, 404820],
#  ['Czech Republic', 'Karlovy Vary', 'Karlovarský', 2011, 53310],
#  ['Czech Republic', 'Jihlava', 'Vysočina', 2011, 51162],
#  ['Czech Republic', 'Hradec Králové', 'Královéhradecký', 2011, 95594],
#  ['Czech Republic', 'Liberec', 'Liberecký', 2011, 104973],
#  ['Czech Republic', 'Ostrava', 'Moravskoslezský', 2011, 311508],
#  ['Czech Republic', 'Olomouc', 'Olomoucký', 2011, 101954],
#  ['Czech Republic', 'Pardubice', 'Pardubický', 2011, 90844],
#  ['Czech Republic', 'Plzeň', 'Plzeňský', 2011, 171346],
#  ['Czech Republic', 'Ústí nad Labem', 'Ústecký', 2011, 98596],
#  ['Czech Republic', 'Zlín', 'Zlínský', 2011, 77137],
#  ['Germany', 'Stuttgart', 'Baden-Württemberg', 2011, 585890],
#  ['Germany', 'Mannheim', 'Baden-Württemberg', 2011, 290117],
#  ['Germany', 'Karlsruhe', 'Baden-Württemberg', 2011, 289173],
#  ['Germany', 'Freiburg', 'Baden-Württemberg', 2011, 209628],
#  ['Germany', 'Heidelberg', 'Baden-Württemberg', 2011, 146751],
#  ['Germany', 'Heilbronn', 'Baden-Württemberg', 2011, 116059],
#  ['Germany', 'Pforzheim', 'Baden-Württemberg', 2011, 114411],
#  ['Germany', 'Ulm', 'Baden-Württemberg', 2011, 116761],
#  ['Germany', 'Reutlingen', 'Baden-Württemberg', 2011, 109799],
#  ['Germany', 'München', 'Bayern', 2011, 1348335],
#  ['Germany', 'Nürnberg', 'Bayern', 2011, 486314],
#  ['Germany', 'Augsburg', 'Bayern', 2011, 267767],
#  ['Germany', 'Würzburg', 'Bayern', 2011, 124297],
#  ['Germany', 'Regensburg', 'Bayern', 2011, 135403],
#  ['Germany', 'Ingolstadt', 'Bayern', 2011, 124927],
#  ['Germany', 'Fürth', 'Bayern', 2011, 115613],
#  ['Germany', 'Erlangen', 'Bayern', 2011, 103719],
#  ['Germany', 'Berlin', 'Berlin', 2011, 3292365],
#  ['Germany', 'Potsdam', 'Brandenburg', 2011, 156021],
#  ['Germany', 'Cottbus', 'Brandenburg', 2011, 99984],
#  ['Germany', 'Bremen', 'Bremen', 2011, 542707],
#  ['Germany', 'Bremerhaven', 'Bremen', 2011, 108156],
#  ['Germany', 'Hamburg', 'Hamburg', 2011, 1706696],
#  ['Germany', 'Wiesbaden', 'Hessen', 2011, 269121],
#  ['Germany', 'Frankfurt am Main', 'Hessen', 2011, 667925],
#  ['Germany', 'Kassel', 'Hessen', 2011, 190765],
#  ['Germany', 'Darmstadt', 'Hessen', 2011, 143499],
#  ['Germany', 'Offenbach am Main', 'Hessen', 2011, 113443],
#  ['Germany', 'Schwerin', 'Mecklenburg-Vorpommern', 2011, 91293],
#  ['Germany', 'Rostock', 'Mecklenburg-Vorpommern', 2011, 200265],
#  ['Germany', 'Hannover', 'Niedersachsen', 2011, 506416],
#  ['Germany', 'Braunschweig', 'Niedersachsen', 2011, 242537],
#  ['Germany', 'Osnabrück', 'Niedersachsen', 2011, 153699],
#  ['Germany', 'Oldenburg', 'Niedersachsen', 2011, 157267],
#  ['Germany', 'Göttingen', 'Niedersachsen', 2011, 115843],
#  ['Germany', 'Wolfsburg', 'Niedersachsen', 2011, 119984],
#  ['Germany', 'Salzgitter', 'Niedersachsen', 2011, 98895],
#  ['Germany', 'Hildesheim', 'Niedersachsen', 2011, 99554],
#  ['Germany', 'Düsseldorf', 'Nordrhein-Westfalen', 2011, 586291],
#  ['Germany', 'Köln', 'Nordrhein-Westfalen', 2011, 1005775],
#  ['Germany', 'Essen', 'Nordrhein-Westfalen', 2011, 566201],
#  ['Germany', 'Dortmund', 'Nordrhein-Westfalen', 2011, 571143],
#  ['Germany', 'Duisburg', 'Nordrhein-Westfalen', 2011, 488468],
#  ['Germany', 'Bochum', 'Nordrhein-Westfalen', 2011, 362286],
#  ['Germany', 'Wuppertal', 'Nordrhein-Westfalen', 2011, 342661],
#  ['Germany', 'Bielefeld', 'Nordrhein-Westfalen', 2011, 326870],
#  ['Germany', 'Gelsenkirchen', 'Nordrhein-Westfalen', 2011, 258766],
#  ['Germany', 'Bonn', 'Nordrhein-Westfalen', 2011, 305765],
#  ['Germany', 'Mönchengladbach', 'Nordrhein-Westfalen', 2011, 255188],
#  ['Germany', 'Münster', 'Nordrhein-Westfalen', 2011, 289576],
#  ['Germany', 'Krefeld', 'Nordrhein-Westfalen', 2011, 222247],
#  ['Germany', 'Aachen', 'Nordrhein-Westfalen', 2011, 236420],
#  ['Germany', 'Oberhausen', 'Nordrhein-Westfalen', 2011, 210216],
#  ['Germany', 'Hagen', 'Nordrhein-Westfalen', 2011, 187944],
#  ['Germany', 'Hamm', 'Nordrhein-Westfalen', 2011, 176037],
#  ['Germany', 'Herne', 'Nordrhein-Westfalen', 2011, 155160],
#  ['Germany', 'Mülheim an der Ruhr', 'Nordrhein-Westfalen', 2011, 166865],
#  ['Germany', 'Solingen', 'Nordrhein-Westfalen', 2011, 155265],
#  ['Germany', 'Leverkusen', 'Nordrhein-Westfalen', 2011, 158984],
#  ['Germany', 'Neuss', 'Nordrhein-Westfalen', 2011, 150568],
#  ['Germany', 'Paderborn', 'Nordrhein-Westfalen', 2011, 142365],
#  ['Germany', 'Recklinghausen', 'Nordrhein-Westfalen', 2011, 115958],
#  ['Germany', 'Remscheid', 'Nordrhein-Westfalen', 2011, 110708],
#  ['Germany', 'Bottrop', 'Nordrhein-Westfalen', 2011, 117311],
#  ['Germany', 'Siegen', 'Nordrhein-Westfalen', 2011, 99187],
#  ['Germany', 'Moers', 'Nordrhein-Westfalen', 2011, 104009],
#  ['Germany', 'Witten', 'Nordrhein-Westfalen', 2011, 96382],
#  ['Germany', 'Bergisch Gladbach', 'Nordrhein-Westfalen', 2011, 108878],
#  ['Germany', 'Mainz', 'Rheinland-Pfalz', 2011, 200344],
#  ['Germany', 'Ludwigshafen', 'Rheinland-Pfalz', 2011, 157584],
#  ['Germany', 'Koblenz', 'Rheinland-Pfalz', 2011, 107825],
#  ['Germany', 'Kaiserslautern', 'Rheinland-Pfalz', 2011, 96340],
#  ['Germany', 'Trier', 'Rheinland-Pfalz', 2011, 105671],
#  ['Germany', 'Saarbrücken', 'Saarland', 2011, 175853],
#  ['Germany', 'Dresden', 'Sachsen', 2011, 512354],
#  ['Germany', 'Leipzig', 'Sachsen', 2011, 502979],
#  ['Germany', 'Chemnitz', 'Sachsen', 2011, 240253],
#  ['Germany', 'Zwickau', 'Sachsen', 2011, 93081],
#  ['Germany', 'Magdeburg', 'Sachsen-Anhalt', 2011, 228144],
#  ['Germany', 'Halle', 'Sachsen-Anhalt', 2011, 229153],
#  ['Germany', 'Kiel', 'Schleswig-Holstein', 2011, 235782],
#  ['Germany', 'Lübeck', 'Schleswig-Holstein', 2011, 210305],
#  ['Germany', 'Erfurt', 'Thüringen', 2011, 200868],
#  ['Germany', 'Gera', 'Thüringen', 2011, 96067],
#  ['Germany', 'Jena', 'Thüringen', 2011, 105739],
#  ['Hungary', 'Pécs', 'Baranya', 2011, 156049],
#  ['Hungary', 'Kecskemét', 'Bács-Kiskun', 2011, 111411],
#  ['Hungary', 'Békéscsaba', 'Békés', 2011, 62050],
#  ['Hungary', 'Miskolc', 'Borsod-Abaúj-Zemplén', 2011, 167754],
#  ['Hungary', 'Szeged', 'Csongrád', 2011, 168048],
#  ['Hungary', 'Hodmezovasarhely', 'Csongrád', 2011, 168048],
#  ['Hungary', 'Székesfehérvár', 'Fejér', 2011, 100570],
#  ['Hungary', 'Győr', 'Győr-Moson-Sopron', 2011, 129527],
#  ['Hungary', 'Debrecen', 'Hajdú-Bihar', 2011, 211320],
#  ['Hungary', 'Eger', 'Heves', 2011, 56569],
#  ['Hungary', 'Tatabánya', 'Komárom-Esztergom', 2011, 67753],
#  ['Hungary', 'Salgotarjan', 'Komárom-Esztergom', 2011, 67753],
#  ['Hungary', 'Kaposvár', 'Somogy', 2011, 66245],
#  ['Hungary', 'Nyíregyháza', 'Szabolcs-Szatmár-Bereg', 2011, 119746],
#  ['Hungary', 'Szolnok', 'Jász-Nagykun-Szolnok', 2011, 72953],
#  ['Hungary', 'Szekszard', 'Jász-Nagykun-Szolnok', 2011, 72953],
#  ['Hungary', 'Szombathely', 'Vas', 2011, 78884],
#  ['Hungary', 'Veszprém', 'Veszprém', 2011, 61721],
#  ['Hungary', 'Zalaegerszeg', 'Zala', 2011, 59499],
#  ['Hungary', 'Budapest', 'Budapest', 2011, 1729040],
#  ['Italy', 'Novara', 'Piemonte', 2011, 101952],
#  ['Italy', 'Torino', 'Piemonte', 2011, 872367],
#  ['Italy', 'Aosta', 'Piemonte', 2011, 872367],
#  ['Italy', 'Bérgamo', 'Lombardia', 2011, 115349],
#  ['Italy', 'Bréscia', 'Lombardia', 2011, 189902],
#  ['Italy', 'Milano', 'Lombardia', 2011, 1242123],
#  ['Italy', 'Monza', 'Lombardia', 2011, 119856],
#  ['Italy', 'Bolzano', 'Trentino-Alto Adige', 2011, 102575],
#  ['Italy', 'Trento', 'Trentino-Alto Adige', 2011, 114198],
#  ['Italy', 'Pádova', 'Veneto', 2011, 206192],
#  ['Italy', 'Verona', 'Veneto', 2011, 252520],
#  ['Italy', 'Vicenza', 'Veneto', 2011, 111500],
#  ['Italy', 'Venézia', 'Veneto', 2011, 261362],
#  ['Italy', 'Trieste', 'Friuli-Venezia Giulia', 2011, 202123],
#  ['Italy', 'La Spezia', 'Liguria', 2011, 92659],
#  ['Italy', 'Génova', 'Liguria', 2011, 586180],
#  ['Italy', 'Bologna', 'Emilia-Romagna', 2011, 371337],
#  ['Italy', 'Ferrara', 'Emilia-Romagna', 2011, 132545],
#  ['Italy', 'Forlí', 'Emilia-Romagna', 2011, 116434],
#  ['Italy', 'Módena', 'Emilia-Romagna', 2011, 179149],
#  ['Italy', 'Parma', 'Emilia-Romagna', 2011, 175895],
#  ['Italy', 'Piacenza', 'Emilia-Romagna', 2011, 100311],
#  ['Italy', 'Ravenna', 'Emilia-Romagna', 2011, 153740],
#  ['Italy', "Réggio nell'Emilia", 'Emilia-Romagna', 2011, 162082],
#  ['Italy', 'Rímini', 'Emilia-Romagna', 2011, 139601],
#  ['Italy', 'Livorno', 'Toscana', 2011, 157052],
#  ['Italy', 'Pisa', 'Toscana', 2011, 85858],
#  ['Italy', 'Firenze', 'Toscana', 2011, 358079],
#  ['Italy', 'Prato', 'Toscana', 2011, 185456],
#  ['Italy', 'Perúgia', 'Umbria', 2011, 162449],
#  ['Italy', 'Terni', 'Umbria', 2011, 109193],
#  ['Italy', 'Ancona', 'Marche', 2011, 100497],
#  ['Italy', 'Roma', 'Lazio', 2011, 2617175],
#  ['Italy', 'Latina', 'Lazio', 2011, 117892],
#  ['Italy', 'Pescara', 'Abruzzo', 2011, 117166],
#  ['Italy', 'LAquila', 'Abruzzo', 2011, 117166],
#  ['Italy', 'Campobasso', 'Abruzzo', 2011, 117166],
#  ['Italy', 'Salerno', 'Campania', 2011, 132608],
#  ['Italy', 'Nápoli', 'Campania', 2011, 962003],
#  ['Italy', 'Torre del Greco', 'Campania', 2011, 85922],
#  ['Italy', 'Giugliano in Campania', 'Campania', 2011, 108793],
#  ['Italy', 'Bari', 'Puglia', 2011, 315933],
#  ['Italy', 'Fóggia', 'Puglia', 2011, 147036],
#  ['Italy', 'Lecce', 'Puglia', 2011, 89916],
#  ['Italy', 'Andria', 'Puglia', 2011, 100052],
#  ['Italy', 'Táranto', 'Puglia', 2011, 200154],
#  ['Italy', 'Potenza', 'Puglia', 2011, 200154],
#  ['Italy', 'Catanzaro', 'Calabria', 2011, 89364],
#  ['Italy', 'Cosenza', 'Calabria', 2011, 69484],
#  ['Italy', 'Réggio di Calabria', 'Calabria', 2011, 180817],
#  ['Italy', 'Palermo', 'Sicilia', 2011, 657561],
#  ['Italy', 'Messina', 'Sicilia', 2011, 243262],
#  ['Italy', 'Catánia', 'Sicilia', 2011, 293902],
#  ['Italy', 'Siracusa', 'Sicilia', 2011, 118385],
#  ['Italy', 'Cágliari', 'Sardegna', 2011, 149883],
#  ['Italy', 'Sássari', 'Sardegna', 2011, 123782],
#  ['Liechtenstein', 'Vaduz', 'No Province', 2012, 5241],
#  ['Slovakia', 'Bratislava', 'Bratislavský', 2011, 411228],
#  ['Slovakia', 'Banská Bystrica', 'Banskobystrický', 2011, 80003],
#  ['Slovakia', 'Žilina', 'Žilinský', 2011, 81494],
#  ['Slovakia', 'Košice', 'Košický', 2011, 240433],
#  ['Slovakia', 'Prešov', 'Prešovský', 2011, 91782],
#  ['Slovakia', 'Nitra', 'Nitriansky', 2011, 78916],
#  ['Slovakia', 'Trenčín', 'Trenčiansky', 2011, 55877],
#  ['Slovakia', 'Trnava', 'Trnavský', 2011, 66358],
#  ['Slovenia', 'Ljubljana', 'No Province', 2013, 282994],
#  ['Slovenia', 'Maribor', 'No Province', 2013, 111374],
#  ['Switzerland', 'Aarau', 'No Province', 2013, 111374],
#  ['Switzerland', 'Herisau', 'No Province', 2013, 111374],
#  ['Switzerland', 'Appenzell', 'No Province', 2013, 111374],
#  ['Switzerland', 'Liestal', 'No Province', 2013, 111374],
#  ['Switzerland', 'Basel', 'Basel-Stadt', 2013, 167386],
#  ['Switzerland', 'Bern', 'Bern', 2013, 128848],
#  ['Switzerland', 'Biel', 'Bern', 2013, 53031],
#  ['Switzerland', 'Fribourg', 'Bern', 2013, 53031],
#  ['Switzerland', 'Genève', 'Genève', 2013, 191557],
#  ['Switzerland', 'Glarus', 'Genève', 2013, 191557],
#  ['Switzerland', 'Chur', 'Genève', 2013, 191557],
#  ['Switzerland', 'Delemont', 'Genève', 2013, 191557],
#  ['Switzerland', 'Luzern', 'Luzern', 2013, 80501],
#  ['Switzerland', 'Neuchatel', 'Luzern', 2013, 80501],
#  ['Switzerland', 'Stans', 'Luzern', 2013, 80501],
#  ['Switzerland', 'Sarnen', 'Luzern', 2013, 80501],
#  ['Switzerland', 'Sankt Gallen', 'Sankt Gallen', 2013, 74581],
#  ['Switzerland', 'Schaffhausen', 'Sankt Gallen', 2013, 74581],
#  ['Switzerland', 'Schwyz', 'Sankt Gallen', 2013, 74581],
#  ['Switzerland', 'Solothurn', 'Sankt Gallen', 2013, 74581],
#  ['Switzerland', 'Frauenfeld', 'Sankt Gallen', 2013, 74581],
#  ['Switzerland', 'Bellinzona', 'Sankt Gallen', 2013, 74581],
#  ['Switzerland', 'Lugano', 'Ticino', 2013, 62792],
#  ['Switzerland', 'Altdorf', 'Ticino', 2013, 62792],
#  ['Switzerland', 'Sion', 'Ticino', 2013, 62792],
#  ['Switzerland', 'Lausanne', 'Vaud', 2013, 132788],
#  ['Switzerland', 'Zug', 'Vaud', 2013, 132788],
#  ['Switzerland', 'Zürich', 'Zürich', 2013, 384786],
#  ['Switzerland', 'Winterthur', 'Zürich', 2013, 105676],
#  ['Belarus', 'Brest', 'Brest', 2009, 309764],
#  ['Belarus', 'Vitebsk', 'Vitebsk', 2009, 347928],
#  ['Belarus', 'Gomel', 'Gomel', 2009, 482652],
#  ['Belarus', 'Grodno', 'Grodno', 2009, 327540],
#  ['Belarus', 'Mogilev', 'Mogilev', 2009, 358279],
#  ['Belarus', 'Bobruysk', 'Mogilev', 2009, 215092],
#  ['Belarus', 'Minsk', 'Minsk City', 2009, 1836808],
#  ['Latvia', 'Rīga', 'No Province', 2013, 696618],
#  ['Lithuania', 'Vilnius', 'No Province', 2013, 538747],
#  ['Lithuania', 'Kaunas', 'No Province', 2013, 307498],
#  ['Lithuania', 'Klaipeda', 'No Province', 2013, 158891],
#  ['Poland', 'Wrocław', 'Dolnośląskie', 2012, 631377],
#  ['Poland', 'Legnica', 'Dolnośląskie', 2012, 102708],
#  ['Poland', 'Wałbrzych', 'Dolnośląskie', 2012, 119216],
#  ['Poland', 'Bydgoszcz', 'Kujawsko-Pomorskie', 2012, 362286],
#  ['Poland', 'Toruń', 'Kujawsko-Pomorskie', 2012, 204847],
#  ['Poland', 'Grudziadz', 'Kujawsko-Pomorskie', 2012, 98726],
#  ['Poland', 'Włocławek', 'Kujawsko-Pomorskie', 2012, 115982],
#  ['Poland', 'Lublin', 'Lubelskie', 2012, 348120],
#  ['Poland', 'Zielona Góra', 'Lubuskie', 2012, 119182],
#  ['Poland', 'Gorzów Wielkopolski', 'Lubuskie', 2012, 124470],
#  ['Poland', 'Łódź', 'Łódzkie', 2012, 722022],
#  ['Poland', 'Kraków', 'Małopolskie', 2012, 759131],
#  ['Poland', 'Tarnów', 'Małopolskie', 2012, 113188],
#  ['Poland', 'Warszawa', 'Mazowieckie', 2012, 1711324],
#  ['Poland', 'Płock', 'Mazowieckie', 2012, 124048],
#  ['Poland', 'Radom', 'Mazowieckie', 2012, 220062],
#  ['Poland', 'Opole', 'Opolskie', 2012, 122120],
#  ['Poland', 'Rzeszów', 'Podkarpackie', 2012, 180776],
#  ['Poland', 'Białystok', 'Podlaskie', 2012, 294675],
#  ['Poland', 'Gdańsk', 'Pomorskie', 2012, 460354],
#  ['Poland', 'Gdynia', 'Pomorskie', 2012, 248574],
#  ['Poland', 'Katowice', 'Śląskie', 2012, 308269],
#  ['Poland', 'Jastrzebie Zdroj', 'Śląskie', 2012, 92465],
#  ['Poland', 'Sosnowiec', 'Śląskie', 2012, 214488],
#  ['Poland', 'Dąbrowa Górnicza', 'Śląskie', 2012, 125063],
#  ['Poland', 'Bytom', 'Śląskie', 2012, 175377],
#  ['Poland', 'Gliwice', 'Śląskie', 2012, 186347],
#  ['Poland', 'Zabrze', 'Śląskie', 2012, 179861],
#  ['Poland', 'Tychy', 'Śląskie', 2012, 129087],
#  ['Poland', 'Ruda Śląska', 'Śląskie', 2012, 142672],
#  ['Poland', 'Rybnik', 'Śląskie', 2012, 140863],
#  ['Poland', 'Chorzów', 'Śląskie', 2012, 111314],
#  ['Poland', 'Częstochowa', 'Śląskie', 2012, 235156],
#  ['Poland', 'Bielsko-Biała', 'Śląskie', 2012, 174291],
#  ['Poland', 'Kielce', 'Świętokrzyskie', 2012, 201363],
#  ['Poland', 'Olsztyn', 'Warmińsko-Mazurskie', 2012, 175482],
#  ['Poland', 'Elbląg', 'Warmińsko-Mazurskie', 2012, 123977],
#  ['Poland', 'Poznań', 'Wielkopolskie', 2012, 552393],
#  ['Poland', 'Kalisz', 'Wielkopolskie', 2012, 104867],
#  ['Poland', 'Szczecin', 'Zachodniopomorskie', 2012, 409211],
#  ['Poland', 'Koszalin', 'Zachodniopomorskie', 2012, 109183],
#  ['Ukraine', 'Cherkasy', 'Cherkas´ka', 2012, 286163],
#  ['Ukraine', 'Chernihiv', 'Chernihivs´ka', 2012, 296723],
#  ['Ukraine', 'Chernivtsi', 'Chernivets´ka', 2012, 255929],
#  ['Ukraine', 'Dnipropetrovs´k', 'Dnipropetrovs´ka', 2012, 999577],
#  ['Ukraine', 'Kryvyi Rih', 'Dnipropetrovs´ka', 2012, 660203],
#  ['Ukraine', 'Dniprodzerzhyns´k', 'Dnipropetrovs´ka', 2012, 242646],
#  ['Ukraine', 'Nikopol´', 'Dnipropetrovs´ka', 2012, 120000],
#  ['Ukraine', 'Donets´k', 'Donets´ka', 2012, 955041],
#  ['Ukraine', 'Mariupol´', 'Donets´ka', 2012, 464457],
#  ['Ukraine', 'Makiïvka', 'Donets´ka', 2012, 356118],
#  ['Ukraine', 'Horlivka', 'Donets´ka', 2012, 258879],
#  ['Ukraine', 'Kramators´k', 'Donets´ka', 2012, 165469],
#  ['Ukraine', 'Ivano-Frankivs´k', 'Ivano-Frankivs´ka', 2012, 224660],
#  ['Ukraine', 'Kharkiv', 'Kharkivs´ka', 2012, 1441362],
#  ['Ukraine', 'Kherson', 'Khersons´ka', 2012, 300666],
#  ['Ukraine', 'Khmel´nyts´kyi', 'Khmel´nyts´ka', 2012, 263703],
#  ['Ukraine', 'Prypjat', 'Kyïvs´ka', 2001, 0],
#  ['Ukraine', 'Kirovohrad', 'Kirovohrads´ka', 2012, 234919],
#  ['Ukraine', 'Luhans´k', 'Luhans´ka', 2012, 427187],
#  ['Ukraine', 'L´viv', 'L´vivs´ka', 2012, 729842],
#  ['Ukraine', 'Mykolaïv', 'Mykolaïvs´ka', 2012, 497032],
#  ['Ukraine', 'Odesa', 'Odes´ka', 2012, 1008162],
#  ['Ukraine', 'Poltava', 'Poltavs´ka', 2012, 297589],
#  ['Ukraine', 'Kremenchuk', 'Poltavs´ka', 2012, 226434],
#  ['Ukraine', 'Rivne', 'Rivnens´ka', 2012, 250174],
#  ['Ukraine', 'Sumy', 'Sums´ka', 2012, 269663],
#  ['Ukraine', 'Ternopil´', 'Ternopil´s´ka', 2012, 217300],
#  ['Ukraine', 'Vinnytsia', 'Vinnyts´ka', 2012, 370814],
#  ['Ukraine', 'Luts´k', 'Volyns´ka', 2012, 213063],
#  ['Ukraine', 'Uzhhorod', 'Zakarpats´ka', 2012, 116556],
#  ['Ukraine', 'Zaporizhzhia', 'Zaporiz´ka', 2012, 772627],
#  ['Ukraine', 'Melitopol´', 'Zaporiz´ka', 2012, 156885],
#  ['Ukraine', 'Zhytomyr', 'Zhytomyrs´ka', 2012, 271895],
#  ['Ukraine', 'Simferopol´', 'Krym', 2012, 335582],
#  ['Ukraine', 'Kerch', 'Krym', 2012, 145845],
#  ['Ukraine', 'Kyïv', 'Kyïv', 2012, 2814258],
#  ['Ukraine', 'Bila Tserkva', 'Kyïv', 2012, 210551],
#  ['Ukraine', 'Sevastopol´', 'Sevastopol´', 2012, 340559],
#  ['Russia', 'Petrozavodsk', 'Karelia', 2013, 268946],
#  ['Russia', 'Syktyvkar', 'Komi', 2010, 235006],
#  ['Russia', 'Ukhta', 'Komi', 2010, 99591],
#  ['Russia', 'Vorkuta', 'Komi', 2010, 70548],
#  ['Russia', 'Arkhangelsk', 'Arkhangel´skaya', 2013, 350985],
#  ['Russia', 'Severodvinsk', 'Arkhangel´skaya', 2010, 192353],
#  ['Russia', 'Vologda', 'Vologodskaya', 2013, 306487],
#  ['Russia', 'Cherepovets', 'Vologodskaya', 2013, 315738],
#  ['Russia', 'Murmansk', 'Murmanskaya', 2013, 302468],
#  ['Russia', 'Kaliningrad', 'Kaliningradskaya', 2013, 441376],
#  ['Russia', 'Sankt Peterburg', 'Sankt-Peterburg', 2013, 5028000],
#  ['Russia', 'Velikij Novgorod', 'Novgorodskaya', 2010, 218717],
#  ['Russia', 'Pskov', 'Pskovskaya', 2010, 203279],
#  ['Russia', 'Bryansk', 'Bryanskaya', 2013, 410837],
#  ['Russia', 'Vladimir', 'Vladimirskaya', 2013, 347930],
#  ['Russia', 'Kovrov', 'Vladimirskaya', 2010, 145214],
#  ['Russia', 'Murom', 'Vladimirskaya', 2010, 116075],
#  ['Russia', 'Ivanovo', 'Ivanovskaya', 2013, 409075],
#  ['Russia', 'Kaluga', 'Kaluzhskaya', 2013, 331351],
#  ['Russia', 'Obninsk', 'Kaluzhskaya', 2010, 104739],
#  ['Russia', 'Kostroma', 'Kostromskaya', 2013, 271445],
#  ['Russia', 'Moskva', 'Moscow', 2013, 11979529],
#  ['Russia', "Podol'sk", 'Moskovskaya', 2010, 187961],
#  ['Russia', 'Železnodorožnyj', 'Moskovskaya', 2010, 131257],
#  ['Russia', 'Krasnogorsk', 'Moskovskaya', 2010, 116896],
#  ['Russia', "L'ubercy", 'Moskovskaya', 2010, 172525],
#  ['Russia', 'Kolomna', 'Moskovskaya', 2010, 144589],
#  ['Russia', 'Mytišči', 'Moskovskaya', 2010, 173160],
#  ['Russia', "Elektrostal'", 'Moskovskaya', 2010, 155196],
#  ['Russia', 'Serpuchov', 'Moskovskaya', 2010, 127041],
#  ['Russia', 'Balašicha', 'Moskovskaya', 2010, 215494],
#  ['Russia', 'Chimki', 'Moskovskaya', 2010, 207425],
#  ['Russia', 'Odincovo', 'Moskovskaya', 2010, 138930],
#  ['Russia', 'Orechovo-Zujevo', 'Moskovskaya', 2010, 120670],
#  ['Russia', 'Noginsk', 'Moskovskaya', 2010, 100072],
#  ['Russia', 'Ščëlkovo', 'Moskovskaya', 2010, 110411],
#  ['Russia', 'Sergijev Posad', 'Moskovskaya', 2010, 111179],
#  ['Russia', 'Korolëv', 'Moskovskaya', 2010, 183402],
#  ['Russia', 'Žukovskij', 'Moskovskaya', 2010, 104736],
#  ['Russia', 'Puškino', 'Moskovskaya', 2010, 102874],
#  ['Russia', 'Orel', 'Orlovskaya', 2013, 318136],
#  ['Russia', 'Ryazan', 'Ryazanskaya', 2013, 527905],
#  ['Russia', 'Smolensk', 'Smolenskaya', 2013, 330970],
#  ['Russia', 'Tver', 'Tverskaya', 2013, 408877],
#  ['Russia', 'Tula', 'Tul´skaya', 2013, 493813],
#  ['Russia', 'Novomoskovsk', 'Tul´skaya', 2010, 131386],
#  ['Russia', 'Yaroslavl', 'Yaroslavskaya', 2013, 599169],
#  ['Russia', 'Rybinsk', 'Yaroslavskaya', 2010, 200771],
#  ['Russia', 'Yoshkar-Ola', 'Mariy-El', 2013, 257015],
#  ['Russia', 'Saransk', 'Mordoviya', 2013, 298287],
#  ['Russia', 'Cheboksary', 'Chuvash', 2013, 464940],
#  ['Russia', 'Novočeboksarsk', 'Chuvash', 2010, 124097],
#  ['Russia', 'Kirov', 'Kirov', 2013, 483176],
#  ['Russia', 'Nizhnii Novgorod', 'Nizhnii Novgorod', 2013, 1259921],
#  ['Russia', 'Dzeržinsk', 'Nizhnii Novgorod', 2010, 240742],
#  ['Russia', 'Arzamas', 'Nizhnii Novgorod', 2010, 106362],
#  ['Russia', 'Belgorod', 'Belgorodskaya', 2013, 373528],
#  ['Russia', 'Staryj Oskol', 'Belgorodskaya', 2010, 221085],
#  ['Russia', 'Voronezh', 'Voronezhskaya', 2013, 1003638],
#  ['Russia', 'Kursk', 'Kurskaya', 2013, 428741],
#  ['Russia', 'Lipetsk', 'Lipetskaya', 2013, 509098],
#  ['Russia', 'Jelec', 'Lipetskaya', 2010, 108404],
#  ['Russia', 'Tambov', 'Tambovskaya', 2013, 281834],
#  ['Russia', 'Elista', 'Kalmykiya', 2010, 103749],
#  ['Russia', 'Kazan', 'Tatarstan', 2013, 1176187],
#  ['Russia', 'Naberezhnye Tchelny', 'Tatarstan', 2013, 519025],
#  ['Russia', 'Nižnekamsk', 'Tatarstan', 2010, 234044],
#  ['Russia', "Al'metjevsk", 'Tatarstan', 2010, 146393],
#  ['Russia', 'Astrakhan', 'Astrakhanskaya', 2013, 527345],
#  ['Russia', 'Volgograd', 'Volgogradskaya', 2013, 1018790],
#  ['Russia', 'Volzhsky', 'Volgogradskaya', 2013, 327356],
#  ['Russia', 'Kamyšin', 'Volgogradskaya', 2010, 119565],
#  ['Russia', 'Penza', 'Penza', 2013, 519900],
#  ['Russia', 'Samara', 'Samara', 2013, 1171598],
#  ['Russia', 'Tolyatti', 'Samara', 2013, 719149],
#  ['Russia', "Syzran'", 'Samara', 2010, 178750],
#  ['Russia', 'Novokujbyševsk', 'Samara', 2010, 108438],
#  ['Russia', 'Saratov', 'Saratov', 2013, 839755],
#  ['Russia', 'Balakovo', 'Saratov', 2010, 199690],
#  ['Russia', "Ėngel's", 'Saratov', 2010, 202419],
#  ['Russia', 'Ulyanovsk', 'Ul´yanovsk', 2013, 615306],
#  ['Russia', 'Dimitrovgrad', 'Ul´yanovsk', 2010, 122580],
#  ['Russia', 'Rostov-na-Donu', 'Rostovskaya', 2013, 1103733],
#  ['Russia', 'Batajsk', 'Rostovskaya', 2010, 111843],
#  ['Russia', 'Taganrog', 'Rostovskaya', 2013, 254783],
#  ['Russia', 'Šachty', 'Rostovskaya', 2010, 239987],
#  ['Russia', 'Novočerkassk', 'Rostovskaya', 2010, 168746],
#  ['Russia', 'Volgodonsk', 'Rostovskaya', 2010, 170841],
#  ['Russia', 'Novošachtinsk', 'Rostovskaya', 2010, 111075],
#  ['Russia', 'Ufa', 'Bashkortostan', 2013, 1077719],
#  ['Russia', 'Sterlitamak', 'Bashkortostan', 2013, 275798],
#  ['Russia', 'Salavat', 'Bashkortostan', 2010, 156095],
#  ['Russia', "Okt'abr'skij", 'Bashkortostan', 2010, 109474],
#  ['Russia', 'Izhevsk', 'Udmurt', 2013, 632913],
#  ['Russia', 'Sarapul', 'Udmurt', 2010, 101381],
#  ['Russia', 'Orenburg', 'Orenburg', 2013, 556127],
#  ['Russia', 'Orsk', 'Orenburg', 2010, 239800],
#  ['Russia', 'Perm', 'Perm', 2013, 1013887],
#  ['Russia', 'Berezniki', 'Perm', 2010, 156466],
#  ['Russia', 'Majkop', 'Adygeya', 2010, 144249],
#  ['Russia', 'Makhachkala', 'Dagestan', 2013, 576194],
#  ['Russia', 'Derbent', 'Dagestan', 2010, 119200],
#  ['Russia', 'Kaspijsk', 'Dagestan', 2010, 100129],
#  ['Russia', 'Chasavjurt', 'Dagestan', 2010, 131187],
#  ['Russia', "Nazran'", 'Ingushskaya', 2010, 93335],
#  ['Russia', "Nal'čik", 'Kabardino-Balkarskaya', 2010, 240203],
#  ['Russia', 'Čerkessk', 'Karachayevo-Cherkesskaya', 2010, 129069],
#  ['Russia', 'Vladikavkaz', 'North Ossetia-Alania', 2013, 308285],
#  ['Russia', 'Grozny', 'Chechenskaya', 2013, 277414],
#  ['Russia', 'Krasnodar', 'Krasnodarskiy', 2013, 784048],
#  ['Russia', 'Sochi', 'Krasnodarskiy', 2013, 368011],
#  ['Russia', 'Novorossiysk', 'Krasnodarskiy', 2013, 251013],
#  ['Russia', 'Armavir', 'Krasnodarskiy', 2010, 188832],
#  ['Russia', 'Stavropol', 'Stavropol´skiy', 2013, 412116],
#  ['Russia', "P'atigorsk", 'Stavropol´skiy', 2010, 142511],
#  ['Russia', 'Nevinnomyssk', 'Stavropol´skiy', 2010, 118360],
#  ['Russia', 'Kislovodsk', 'Stavropol´skiy', 2010, 128553],
#  ['Russia', 'Jessentuki', 'Stavropol´skiy', 2010, 100996],
#  ['Russia', 'Neftekamsk', 'Stavropol´skiy', 2010, 121733],
#  ['Russia', 'Kurgan', 'Kurgan', 2013, 325565],
#  ['Russia', 'Yekaterinburg', 'Sverdlov', 2013, 1396074],
#  ['Russia', 'Nizhny Tagil', 'Sverdlov', 2013, 358378],
#  ['Russia', "Kamensk-Ural'skij", 'Sverdlov', 2010, 174689],
#  ['Russia', "Pervoural'sk", 'Sverdlov', 2010, 124528],
#  ['Russia', 'Chelyabinsk', 'Chelyabinsk', 2013, 1156201],
#  ['Russia', 'Magnitogorsk', 'Chelyabinsk', 2013, 411880],
#  ['Russia', 'Zlatoust', 'Chelyabinsk', 2010, 174962],
#  ['Russia', 'Miass', 'Chelyabinsk', 2010, 151751],
#  ['Russia', 'Kopejsk', 'Chelyabinsk', 2010, 137601],
#  ['Russia', 'Gorno Altaysk', 'Altay', 2010, 56933],
#  ['Russia', 'Barnaul', 'Altayskiy', 2013, 629681],
#  ['Russia', 'Bijsk', 'Altayskiy', 2010, 210115],
#  ['Russia', 'Rubcovsk', 'Altayskiy', 2010, 147002],
#  ['Russia', 'Kemerovo', 'Kemerov', 2013, 540095],
#  ['Russia', 'Novokuznetsk', 'Kemerov', 2013, 549182],
#  ['Russia', 'Prokopjevsk', 'Kemerov', 2010, 210130],
#  ['Russia', 'Novosibirsk', 'Novosibirsk', 2013, 1523801],
#  ['Russia', 'Omsk', 'Omsk', 2013, 1160670],
#  ['Russia', 'Tomsk', 'Tomsk', 2013, 547989],
#  ['Russia', 'Seversk', 'Tomsk', 2010, 108590],
#  ['Russia', 'Tyumen', 'Tyumen', 2013, 634171],
#  ['Russia', 'Ulan-Ude', 'Buryat', 2013, 416079],
#  ['Russia', 'Kyzyl', 'Tyva', 2010, 109918],
#  ['Russia', 'Abakan', 'Khakasiya', 2010, 165214],
#  ['Russia', 'Krasnoyarsk', 'Krasnoyarsk', 2013, 1016385],
#  ['Russia', "Noril'sk", 'Krasnoyarsk', 2010, 175365],
#  ['Russia', 'Ačinsk', 'Krasnoyarsk', 2010, 109155],
#  ['Russia', 'Irkutsk', 'Irkutsk', 2013, 606137],
#  ['Russia', 'Angarsk', 'Irkutsk', 2010, 233567],
#  ['Russia', 'Bratsk', 'Irkutsk', 2010, 246319],
#  ['Russia', 'Chita', 'Zabaykalskiy', 2013, 331346],
#  ['Russia', 'Yakutsk', 'Sakha', 2013, 286456],
#  ['Russia', 'Birobidzhan', 'Jewish ao.', 2010, 75413],
#  ['Russia', 'Anadyr', 'Chukotka', 2010, 13045],
#  ['Russia', 'Vladivostok', 'Primorskiy', 2013, 600378],
#  ['Russia', 'Nachodka', 'Primorskiy', 2010, 159719],
#  ['Russia', 'Ussurijsk', 'Primorskiy', 2010, 158004],
#  ['Russia', 'Khabarovsk', 'Khabarov', 2013, 593636],
#  ['Russia', 'Komsomolsk-na-Amure', 'Khabarov', 2013, 257891],
#  ['Russia', 'Blagoveščensk', 'Amur', 2010, 214390],
#  ['Russia', 'Petropavlovsk-Kamčatskij', 'Kamchatka', 2010, 179780],
#  ['Russia', 'Magadan', 'Magadan', 2010, 95982],
#  ['Russia', 'Okhotsk', 'Magadan', 2010, 4215],
#  ['Russia', 'Južno-Sachalinsk', 'Sakhalin', 2010, 181728],
#  ['Russia', 'Khanty Mansijsk', 'Khanty Mansi ao', 2010, 80151],
#  ['Russia', 'Surgut', 'Khanty Mansi ao', 2013, 325511],
#  ['Russia', 'Nizhnevartovsk', 'Khanty Mansi ao', 2013, 263228],
#  ['Russia', 'Neftejugansk', 'Khanty Mansi ao', 2010, 122855],
#  ['Russia', 'Salekhard', 'Yamalo Nenets ao', 2010, 42544],
#  ['Russia', "Nojabr'sk", 'Yamalo Nenets ao', 2010, 110620],
#  ['Russia', 'Novyj Urengoj', 'Yamalo Nenets ao', 2010, 104107],
#  ['Belgium', 'Bruxelles', 'Bruxelles', 2013, 168576],
#  ['Belgium', 'Schaerbeek', 'Bruxelles', 2013, 130587],
#  ['Belgium', 'Molenbeek-Saint-Jean', 'Bruxelles', 2013, 94653],
#  ['Belgium', 'Anderlecht', 'Bruxelles', 2013, 113462],
#  ['Belgium', 'Antwerpen', 'Antwerpen', 2013, 507911],
#  ['Belgium', 'Gent', 'Oost-Vlaanderen', 2013, 248813],
#  ['Belgium', 'Charleroi', 'Hainaut', 2013, 203753],
#  ['Belgium', 'Mons', 'Hainaut', 2013, 93941],
#  ['Belgium', 'Liège', 'Liège', 2013, 195931],
#  ['Belgium', 'Hasselt', 'Limburg', 2013, 75579],
#  ['Belgium', 'Arlon', 'Luxembourg', 2013, 28759],
#  ['Belgium', 'Namur', 'Namur', 2013, 110500],
#  ['Belgium', 'Brugge', 'West-Vlaanderen', 2013, 117577],
#  ['Belgium', 'Wavre', 'West-Vlaanderen', 2013, 117577],
#  ['Belgium', 'Leuven', 'Vlaams-Brabant', 2013, 97692],
#  ['Luxembourg', 'Luxembourg', 'No Province', 2012, 99852],
#  ['Netherlands', 'Groningen', 'Groningen', 2014, 198023],
#  ['Netherlands', 'Leeuwarden', 'Friesland', 2014, 108145],
#  ['Netherlands', 'Assen', 'Friesland', 2014, 108145],
#  ['Netherlands', 'Enschede', 'Overijssel', 2014, 158494],
#  ['Netherlands', 'Zwolle', 'Overijssel', 2014, 123440],
#  ['Netherlands', 'Lelystad', 'Flevoland', 2014, 76252],
#  ['Netherlands', 'Almere', 'Flevoland', 2014, 196244],
#  ['Netherlands', 'Arnhem', 'Gelderland', 2014, 150989],
#  ['Netherlands', 'Nijmegen', 'Gelderland', 2014, 168810],
#  ['Netherlands', 'Apeldoorn', 'Gelderland', 2014, 157540],
#  ['Netherlands', 'Utrecht', 'Utrecht', 2014, 330081],
#  ['Netherlands', 'Amersfoort', 'Utrecht', 2014, 151270],
#  ['Netherlands', 'Amsterdam', 'Noord-Holland', 2014, 812895],
#  ['Netherlands', 'Haarlem', 'Noord-Holland', 2014, 155361],
#  ['Netherlands', 'Zaanstad', 'Noord-Holland', 2014, 151058],
#  ['Netherlands', 'Hilversum', 'Noord-Holland', 2014, 86738],
#  ['Netherlands', 'Den Haag', 'Zuid-Holland', 2014, 509623],
#  ['Netherlands', 'Rotterdam', 'Zuid-Holland', 2014, 619180],
#  ['Netherlands', 'Dordrecht', 'Zuid-Holland', 2014, 118780],
#  ['Netherlands', 'Leiden', 'Zuid-Holland', 2014, 121387],
#  ['Netherlands', 'Middelburg', 'Zuid-Holland', 2014, 121387],
#  ['Netherlands', "'s-Hertogenbosch", 'Noord-Brabant', 2014, 143822],
#  ['Netherlands', 'Eindhoven', 'Noord-Brabant', 2014, 221279],
#  ['Netherlands', 'Tilburg', 'Noord-Brabant', 2014, 210283],
#  ['Netherlands', 'Breda', 'Noord-Brabant', 2014, 180263],
#  ['Netherlands', 'Maastricht', 'Limburg', 2014, 122243],
#  ['Netherlands', 'Heerlen', 'Limburg', 2014, 88139],
#  ['Netherlands', 'Sittard-Geleen', 'Limburg', 2014, 93726],
#  ['Bosnia and Herzegovina',
#   'Sarajevo',
#   'Federacija Bosne i Hercegovine',
#   2013,
#   291422],
#  ['Bosnia and Herzegovina',
#   'Tuzla',
#   'Federacija Bosne i Hercegovine',
#   2013,
#   120441],
#  ['Bosnia and Herzegovina',
#   'Zenica',
#   'Federacija Bosne i Hercegovine',
#   2013,
#   115134],
#  ['Bosnia and Herzegovina',
#   'Mostar',
#   'Federacija Bosne i Hercegovine',
#   2013,
#   113169],
#  ['Bosnia and Herzegovina', 'Banja Luka', 'Republika Srpska', 2013, 199191],
#  ['Bosnia and Herzegovina', 'Bijeljina', 'Republika Srpska', 2013, 114663],
#  ['Bosnia and Herzegovina', 'Brčko', 'Brčko', 2013, 93028],
#  ['Croatia', 'Zagreb', 'No Province', 2011, 686568],
#  ['Croatia', 'Split', 'No Province', 2011, 165893],
#  ['Croatia', 'Rijeka', 'No Province', 2011, 127498],
#  ['Croatia', 'Osijek', 'No Province', 2011, 83496],
#  ['Croatia', 'Zadar', 'No Province', 2011, 70674],
#  ['Bulgaria', 'Sofia', 'No Province', 2011, 1270284],
#  ['Bulgaria', 'Plovdiv', 'No Province', 2011, 331796],
#  ['Bulgaria', 'Varna', 'No Province', 2011, 330486],
#  ['Bulgaria', 'Burgas', 'No Province', 2011, 197301],
#  ['Bulgaria', 'Ruse', 'No Province', 2011, 146609],
#  ['Bulgaria', 'Stara Zagora', 'No Province', 2011, 136363],
#  ['Romania', 'Alba Iulia', 'No Province', 2011, 136363],
#  ['Romania', 'Arad', 'Arad', 2011, 159074],
#  ['Romania', 'Piteşti', 'Argeş', 2011, 155383],
#  ['Romania', 'Bacău', 'Bacău', 2011, 144307],
#  ['Romania', 'Oradea', 'Bihor', 2011, 196367],
#  ['Romania', 'Bistrita', 'Bihor', 2011, 196367],
#  ['Romania', 'Botoşani', 'Botoşani', 2011, 106847],
#  ['Romania', 'Brăila', 'Brăila', 2011, 180302],
#  ['Romania', 'Braşov', 'Braşov', 2011, 253200],
#  ['Romania', 'Bucureşti', 'Bucureşti', 2011, 1883425],
#  ['Romania', 'Buzău', 'Buzău', 2011, 115494],
#  ['Romania', 'Calarasi', 'Buzău', 2011, 115494],
#  ['Romania', 'Resita', 'Buzău', 2011, 115494],
#  ['Romania', 'Cluj-Napoca', 'Cluj', 2011, 324576],
#  ['Romania', 'Constanţa', 'Constanţa', 2011, 283872],
#  ['Romania', 'Sfintu Gheorghe', 'Constanţa', 2011, 283872],
#  ['Romania', 'Targoviste', 'Constanţa', 2011, 283872],
#  ['Romania', 'Craiova', 'Dolj', 2011, 269506],
#  ['Romania', 'Galaţi', 'Galaţi', 2011, 249432],
#  ['Romania', 'Giurgiu', 'Galaţi', 2011, 249432],
#  ['Romania', 'Tirgu Jiu', 'Galaţi', 2011, 249432],
#  ['Romania', 'Miercurea Ciuc', 'Galaţi', 2011, 249432],
#  ['Romania', 'Deva', 'Galaţi', 2011, 249432],
#  ['Romania', 'Slobozia', 'Galaţi', 2011, 249432],
#  ['Romania', 'Iaşi', 'Iaşi', 2011, 290422],
#  ['Romania', 'Baia Mare', 'Maramureş', 2011, 123738],
#  ['Romania', 'Drobeta-Turnu Severin', 'Mehedinţi', 2011, 92617],
#  ['Romania', 'Târgu Mureş', 'Mureş', 2011, 134290],
#  ['Romania', 'Piatra-Neamţ', 'Neamţ', 2011, 85055],
#  ['Romania', 'Slatina', 'Neamţ', 2011, 85055],
#  ['Romania', 'Ploieşti', 'Prahova', 2011, 209945],
#  ['Romania', 'Zalau', 'Prahova', 2011, 209945],
#  ['Romania', 'Satu Mare', 'Satu-Mare', 2011, 102411],
#  ['Romania', 'Sibiu', 'Sibiu', 2011, 147245],
#  ['Romania', 'Suceava', 'Suceava', 2011, 92121],
#  ['Romania', 'Alexandria', 'Suceava', 2011, 92121],
#  ['Romania', 'Timişoara', 'Timiş', 2011, 319279],
#  ['Romania', 'Tulcea', 'Timiş', 2011, 319279],
#  ['Romania', 'Vaslui', 'Timiş', 2011, 319279],
#  ['Romania', 'Râmnicu Vâlcea', 'Vâlcea', 2011, 98776],
#  ['Romania', 'Focsani', 'Vâlcea', 2011, 98776],
#  ['Turkey', 'Adana', 'Adana', 2012, 1636229],
#  ['Turkey', 'Adiyaman', 'Adıyaman', 2012, 217463],
#  ['Turkey', 'Afyonkarahisar', 'Afyonkarahisar', 2012, 186991],
#  ['Turkey', 'Agri', 'Ağrı', 2012, 107839],
#  ['Turkey', 'Aksaray', 'Aksaray', 2012, 186599],
#  ['Turkey', 'Amasya', 'Amasya', 2012, 91874],
#  ['Turkey', 'Ankara', 'Ankara', 2012, 4630735],
#  ['Turkey', 'Antalya', 'Antalya', 2012, 1073794],
#  ['Turkey', 'Artvin', 'Antalya', 2012, 1073794],
#  ['Turkey', 'Aydin', 'Aydın', 2012, 195951],
#  ['Turkey', 'Balikesir', 'Balıkesir', 2012, 267903],
#  ['Turkey', 'Batman', 'Batman', 2012, 348963],
#  ['Turkey', 'Bayburt', 'Batman', 2012, 348963],
#  ['Turkey', 'Bilecik', 'Batman', 2012, 348963],
#  ['Turkey', 'Bingol', 'Bingöl', 2012, 98424],
#  ['Turkey', 'Bitlis', 'Bingöl', 2012, 98424],
#  ['Turkey', 'Bolu', 'Bolu', 2012, 131264],
#  ['Turkey', 'Burdur', 'Bolu', 2012, 131264],
#  ['Turkey', 'Bursa', 'Bursa', 2012, 1734705],
#  ['Turkey', 'İnegöl', 'Bursa', 2012, 177617],
#  ['Turkey', 'Canakkale', 'Çanakkale', 2012, 111137],
#  ['Turkey', 'Cankiri', 'Çanakkale', 2012, 111137],
#  ['Turkey', 'Corum', 'Çorum', 2012, 231146],
#  ['Turkey', 'Denizli', 'Denizli', 2012, 525497],
#  ['Turkey', 'Diyarbakir', 'Diyarbakır', 2012, 892713],
#  ['Turkey', 'Edirne', 'Edirne', 2012, 148474],
#  ['Turkey', 'Elazig', 'Elazığ', 2012, 347857],
#  ['Turkey', 'Erzincan', 'Erzincan', 2012, 96474],
#  ['Turkey', 'Erzurum', 'Erzurum', 2012, 384399],
#  ['Turkey', 'Eskisehir', 'Eskişehir', 2012, 659924],
#  ['Turkey', 'Gaziantep', 'Gaziantep', 2012, 1438373],
#  ['Turkey', 'Giresun', 'Giresun', 2012, 100712],
#  ['Turkey', 'Gumushane', 'Giresun', 2012, 100712],
#  ['Turkey', 'Hakkari', 'Giresun', 2012, 100712],
#  ['Turkey', 'Iskenderun', 'Hatay', 2012, 184833],
#  ['Turkey', 'Hatay', 'Hatay', 2012, 216960],
#  ['Turkey', 'Mersin', 'Mersin', 2012, 876958],
#  ['Turkey', 'Tarsus', 'Mersin', 2012, 245671],
#  ['Turkey', 'Isparta', 'Isparta', 2012, 198385],
#  ['Turkey', 'Istanbul', 'İstanbul', 2012, 13710512],
#  ['Turkey', 'Izmir', 'İzmir', 2012, 3401994],
#  ['Turkey', 'Karaman', 'Karaman', 2012, 141630],
#  ['Turkey', 'Kahramanmaraş', 'Kahramanmaraş', 2012, 443575],
#  ['Turkey', 'Kars', 'Kars', 2012, 78100],
#  ['Turkey', 'Kastamonu', 'Kastamonu', 2012, 96217],
#  ['Turkey', 'Kayseri', 'Kayseri', 2012, 1004276],
#  ['Turkey', 'Kirikkale', 'Kırıkkale', 2012, 192473],
#  ['Turkey', 'Kirklareli', 'Kırıkkale', 2012, 192473],
#  ['Turkey', 'Luleburgaz', 'Kırklareli', 2012, 105279],
#  ['Turkey', 'Kirsehir', 'Kırşehir', 2012, 114244],
#  ['Turkey', 'Kocaeli', 'Kocaeli', 2012, 1527407],
#  ['Turkey', 'Gebze', 'Kocaeli', 2010, 290868],
#  ['Turkey', 'Konya', 'Konya', 2012, 1107886],
#  ['Turkey', 'Kütahya', 'Kütahya', 2012, 224898],
#  ['Turkey', 'Malatya', 'Malatya', 2012, 426381],
#  ['Turkey', 'Manisa', 'Manisa', 2012, 309050],
#  ['Turkey', 'Mardin', 'Mardin', 2012, 86948],
#  ['Turkey', 'Kızıltepe', 'Mardin', 2012, 147585],
#  ['Turkey', 'Mugla', 'Mardin', 2012, 147585],
#  ['Turkey', 'Mus', 'Muş', 2012, 81764],
#  ['Turkey', 'Nevsehir', 'Nevşehir', 2012, 92068],
#  ['Turkey', 'Nigde', 'Niğde', 2012, 118186],
#  ['Turkey', 'Ordu', 'Ordu', 2012, 147913],
#  ['Turkey', 'Rize', 'Rize', 2012, 104508],
#  ['Turkey', 'Sakarya', 'Sakarya', 2012, 590498],
#  ['Turkey', 'Samsun', 'Samsun', 2012, 547778],
#  ['Turkey', 'Şanlıurfa', 'Şanlıurfa', 2012, 526247],
#  ['Turkey', 'Siirt', 'Siirt', 2012, 135350],
#  ['Turkey', 'Sinop', 'Siirt', 2012, 135350],
#  ['Turkey', 'Sirnak', 'Siirt', 2012, 135350],
#  ['Turkey', 'Sivas', 'Sivas', 2012, 312587],
#  ['Turkey', 'Tekirdag', 'Tekirdağ', 2012, 150112],
#  ['Turkey', 'Çorlu', 'Tekirdağ', 2012, 235354],
#  ['Turkey', 'Tokat', 'Tokat', 2012, 132437],
#  ['Turkey', 'Trabzon', 'Trabzon', 2012, 243735],
#  ['Turkey', 'Tunceli', 'Trabzon', 2012, 243735],
#  ['Turkey', 'Usak', 'Uşak', 2012, 187886],
#  ['Turkey', 'Van', 'Van', 2012, 370190],
#  ['Turkey', 'Yozgat', 'Yozgat', 2012, 78328],
#  ['Turkey', 'Zonguldak', 'Zonguldak', 2012, 109080],
#  ['Turkey', 'Bartin', 'Zonguldak', 2012, 109080],
#  ['Turkey', 'Karabük', 'Karabük', 2012, 110537],
#  ['Turkey', 'Ardahan', 'Karabük', 2012, 110537],
#  ['Turkey', 'Iğdır', 'Iğdır', 2012, 82656],
#  ['Turkey', 'Yalova', 'Yalova', 2012, 102874],
#  ['Turkey', 'Kilis', 'Kilis', 2012, 85119],
#  ['Turkey', 'Duzce', 'Düzce', 2012, 135557],
#  ['Turkey', 'Osmaniye', 'Osmaniye', 2012, 209255],
#  ['Denmark', 'Aalborg', 'Nordjylland', 2012, 104885],
#  ['Denmark', 'Viborg', 'Nordjylland', 2012, 104885],
#  ['Denmark', 'Århus', 'Midtjylland', 2012, 252213],
#  ['Denmark', 'Randers', 'Midtjylland', 2012, 61121],
#  ['Denmark', 'Vejle', 'Syddanmark', 2012, 51804],
#  ['Denmark', 'Odense', 'Syddanmark', 2012, 168798],
#  ['Denmark', 'Esbjerg', 'Syddanmark', 2012, 71579],
#  ['Denmark', 'Hilleroed', 'Syddanmark', 2012, 71579],
#  ['Denmark', 'København', 'Hovedstaden', 2012, 549050],
#  ['Denmark', 'Soroe', 'Hovedstaden', 2012, 549050],
#  ['Estonia', 'Tallinn', 'No Province', 2010, 399340],
#  ['Estonia', 'Tartu', 'No Province', 2010, 103284],
#  ['Faroe Islands', 'Tórshavn', 'No Province', 2013, 12245],
#  ['Finland', 'Mariehamn', 'Aland', 2007, 10851],
#  ['Finland', 'Tampere', 'Haeme', 2014, 220678],
#  ['Finland', 'Lahti', 'Haeme', 2014, 103396],
#  ['Finland', 'Hämeenlinna', 'Haeme', 2014, 67803],
#  ['Finland', 'Kuopio', 'Kuopio', 2014, 106475],
#  ['Finland', 'Lappeenranta', 'Kymi', 2014, 72617],
#  ['Finland', 'Kotka', 'Kymi', 2014, 54714],
#  ['Finland', 'Rovaniemi', 'Lappia', 2014, 61244],
#  ['Finland', 'Mikkeli', 'Mikkeli', 2014, 54633],
#  ['Finland', 'Jyväskylä', 'Suomi', 2014, 134862],
#  ['Finland', 'Joensuu', 'Pohjols-Karjala', 2014, 74332],
#  ['Finland', 'Oulu', 'Oulu', 2014, 194181],
#  ['Finland', 'Pori', 'Turku-Pori', 2014, 83457],
#  ['Finland', 'Turku', 'Turku-Pori', 2014, 182154],
#  ['Finland', 'Helsinki', 'Uusimaa', 2014, 614535],
#  ['Finland', 'Espoo', 'Uusimaa', 2014, 261654],
#  ['Finland', 'Vaasa', 'Vaasa', 2014, 66415],
#  ['Norway', 'Oslo', 'Oslo', 2013, 623966],
#  ['Norway', 'Sandvika', 'Akershus', 2013, 116677],
#  ['Norway', 'Moss', 'Østfold', 1987, 24517],
#  ['Norway', 'Hamar', 'Hedmark', 1987, 15685],
#  ['Norway', 'Lillehammer', 'Oppland', 1987, 22118],
#  ['Norway', 'Drammen', 'Buskerud', 2013, 65473],
#  ['Norway', 'Tonsberg', 'Vestfold', 1987, 8984],
#  ['Norway', 'Skien', 'Telemark', 2013, 53015],
#  ['Norway', 'Arendal', 'Aust-Agder', 1987, 12174],
#  ['Norway', 'Kristiansand', 'Vest-Agder', 2013, 84476],
#  ['Norway', 'Stavanger', 'Rogaland', 2013, 129191],
#  ['Norway', 'Bergen', 'Hordaland', 2013, 267950],
#  ['Norway', 'Hermannsverk', 'Sogn og Fjordane', 1987, 706],
#  ['Norway', 'Molde', 'Møre og Romsdal', 1987, 21448],
#  ['Norway', 'Trondheim', 'Sør-Trøndelag', 2013, 179692],
#  ['Norway', 'Steinkjer', 'Nord-Trøndelag', 1987, 20480],
#  ['Norway', 'Svolvaer', 'Nordland', 1987, 4500],
#  ['Norway', 'Narvik', 'Nordland', 1987, 18754],
#  ['Norway', 'Bodoe', 'Nordland', 1987, 34479],
#  ['Norway', 'Tromsø', 'Troms', 2013, 70358],
#  ['Norway', 'Hammerfest', 'Finnmark', 1987, 7089],
#  ['Norway', 'Vadsoe', 'Finnmark', 1987, 5961],
#  ['Sweden', 'Göteborg', 'Västra Götaland', 2012, 526089],
#  ['Sweden', 'Vanersborg', 'Västra Götaland', 1987, 35804],
#  ['Sweden', 'Mariestad', 'Västra Götaland', 1987, 24255],
#  ['Sweden', 'Borås', 'Västra Götaland', 2012, 104867],
#  ['Sweden', 'Karlskrona', 'Blekinge', 1987, 59007],
#  ['Sweden', 'Gävle', 'Gävleborg', 2012, 96170],
#  ['Sweden', 'Visby', 'Gotland', 1987, 20000],
#  ['Sweden', 'Halmstad', 'Halland', 2012, 93231],
#  ['Sweden', 'Ostersund', 'Jämtland', 1987, 56662],
#  ['Sweden', 'Jönköping', 'Jönköping', 2012, 129478],
#  ['Sweden', 'Kalmar', 'Kalmar', 1987, 54554],
#  ['Sweden', 'Falun', 'Dalarna', 1987, 51900],
#  ['Sweden', 'Malmö', 'Skåne', 2012, 307758],
#  ['Sweden', 'Helsingborg', 'Skåne', 2012, 132011],
#  ['Sweden', 'Kristianstad', 'Skåne', 2012, 80507],
#  ['Sweden', 'Lund', 'Skåne', 2012, 112950],
#  ['Sweden', 'Växjö', 'Kronoberg', 2012, 84800],
#  ['Sweden', 'Lulea', 'Norrbotten', 1987, 66526],
#  ['Sweden', 'Jokkmokk', 'Norrbotten', 1987, 6822],
#  ['Sweden', 'Örebro', 'Örebro', 2012, 138952],
#  ['Sweden', 'Linköping', 'Östergötland', 2012, 148521],
#  ['Sweden', 'Norrköping', 'Östergötland', 2012, 132124],
#  ['Sweden', 'Nykoping', 'Södermanland', 1987, 64199],
#  ['Sweden', 'Eskilstuna', 'Södermanland', 2012, 98765],
#  ['Sweden', 'Stockholm', 'Stockholm', 2012, 881235],
#  ['Sweden', 'Huddinge', 'Stockholm', 2012, 101010],
#  ['Sweden', 'Uppsala', 'Uppsala', 2012, 202625],
#  ['Sweden', 'Karlstad', 'Värmland', 2012, 86929],
#  ['Sweden', 'Umeå', 'Västerbotten', 2012, 117294],
#  ['Sweden', 'Harnosand', 'Västernorrland', 1987, 27287],
#  ['Sweden', 'Västerås', 'Västmanland', 2012, 140499],
#  ['Monaco', 'Monaco', 'No Province', 2008, 975],
#  ['Gibraltar', 'Gibraltar', 'No Province', 2008, 975],
#  ['Guernsey', 'Saint Peter Port', 'No Province', 2008, 975],
#  ['Holy See', 'Vatican City', 'No Province', 2014, 842],
#  ['Ceuta', 'Ceuta', 'No Province', 2011, 82376],
#  ['Melilla', 'Melilla', 'No Province', 2011, 78476],
#  ['Iceland', 'Reykjavik', 'No Province', 2011, 118061],
#  ['Iceland', 'Keflavik', 'No Province', 2011, 13862],
#  ['Iceland', 'Hafnarfjordur', 'No Province', 2011, 26099],
#  ['Iceland', 'Akureyri', 'No Province', 2011, 17490],
#  ['Ireland', 'Dublin', 'No Province', 2011, 525383],
#  ['Ireland', 'Cork', 'No Province', 2011, 118912],
#  ['Ireland', 'Galway', 'No Province', 2011, 75414],
#  ['Ireland', 'Limerick', 'No Province', 2011, 56779],
#  ['San Marino', 'San Marino', 'No Province', 2012, 4227],
#  ['Jersey', 'Saint Helier', 'No Province', 2012, 4227],
#  ['Malta', 'Valletta', 'No Province', 2010, 5748],
#  ['Malta', 'Victoria', 'No Province', 2010, 6252],
#  ['Isle of Man', 'Douglas', 'No Province', 2010, 6252],
#  ['Moldova', 'Chişinău', 'No Province', 2010, 663400],
#  ['Moldova', 'Tiraspol', 'No Province', 2010, 148917],
#  ['Moldova', 'Bălţi', 'No Province', 2010, 143300],
#  ['Portugal', 'Aveiro', 'Aveiro', 2001, 53496],
#  ['Portugal', 'Beja', 'Aveiro', 2001, 53496],
#  ['Portugal', 'Braga', 'Braga', 2001, 114003],
#  ['Portugal', 'Braganca', 'Braga', 2001, 114003],
#  ['Portugal', 'Castelo Branco', 'Braga', 2001, 114003],
#  ['Portugal', 'Coimbra', 'Coimbra', 2001, 118016],
#  ['Portugal', 'Evora', 'Coimbra', 2001, 118016],
#  ['Portugal', 'Faro', 'Coimbra', 2001, 118016],
#  ['Portugal', 'Guarda', 'Coimbra', 2001, 118016],
#  ['Portugal', 'Leiria', 'Leiria', 2001, 50608],
#  ['Portugal', 'Lisboa', 'Lisboa', 2001, 559248],
#  ['Portugal', 'Amadora', 'Lisboa', 2001, 89232],
#  ['Portugal', 'Barreiro', 'Lisboa', 2011, 79042],
#  ['Portugal', 'Almada', 'Lisboa', 2011, 49578],
#  ['Portugal', 'Portalegre', 'Lisboa', 2011, 49578],
#  ['Portugal', 'Oporto', 'Porto', 2001, 266790],
#  ['Portugal', 'Vila Nova de Gaia', 'Porto', 2001, 72576],
#  ['Portugal', 'Santarem', 'Porto', 2001, 72576],
#  ['Portugal', 'Setúbal', 'Setubal', 2001, 91108],
#  ['Portugal', 'Viana do Castelo', 'Setubal', 2001, 91108],
#  ['Portugal', 'Vila Real', 'Setubal', 2001, 91108],
#  ['Portugal', 'Viseu', 'Setubal', 2001, 91108],
#  ['Portugal', 'Ponta Delgada', 'Azores', 2002, 46102],
#  ['Portugal', 'Funchal', 'Madeira', 2001, 112362],
#  ['Svalbard', 'Longyearbyen', 'Madeira', 2001, 112362],
#  ['United Kingdom', 'Newcastle upon Tyne', 'North East', 2011, 268064],
#  ['United Kingdom', 'Sunderland', 'North East', 2011, 174286],
#  ['United Kingdom', 'Gateshead', 'North East', 2011, 120046],
#  ['United Kingdom', 'Middlesbrough', 'North East', 2011, 174700],
#  ['United Kingdom', 'Manchester', 'North West', 2011, 510746],
#  ['United Kingdom', 'Wigan', 'North West', 2011, 103608],
#  ['United Kingdom', 'Stockport', 'North West', 2011, 105878],
#  ['United Kingdom', 'Bolton', 'North West', 2011, 194189],
#  ['United Kingdom', 'Salford', 'North West', 2011, 103886],
#  ['United Kingdom', 'Oldham', 'North West', 2011, 96555],
#  ['United Kingdom', 'Rochdale', 'North West', 2011, 107926],
#  ['United Kingdom', 'Warrington', 'North West', 2011, 165456],
#  ['United Kingdom', 'Blackpool', 'North West', 2011, 147663],
#  ['United Kingdom', 'Blackburn', 'North West', 2011, 117963],
#  ['United Kingdom', 'Liverpool', 'North West', 2011, 552267],
#  ['United Kingdom', 'Birkenhead', 'North West', 2011, 142968],
#  ['United Kingdom', 'St Helens', 'North West', 2011, 102885],
#  ['United Kingdom', 'Preston', 'North West', 2011, 97886],
#  ['United Kingdom', 'Leeds', 'Yorkshire and the Humber', 2011, 474632],
#  ['United Kingdom', 'Wakefield', 'Yorkshire and the Humber', 2011, 99251],
#  ['United Kingdom', 'Bradford', 'Yorkshire and the Humber', 2011, 349561],
#  ['United Kingdom', 'Huddersfield', 'Yorkshire and the Humber', 2011, 162949],
#  ['United Kingdom', 'Sheffield', 'Yorkshire and the Humber', 2011, 518090],
#  ['United Kingdom', 'Doncaster', 'Yorkshire and the Humber', 2011, 109805],
#  ['United Kingdom', 'Rotherham', 'Yorkshire and the Humber', 2011, 109691],
#  ['United Kingdom', 'York', 'Yorkshire and the Humber', 2011, 152841],
#  ['United Kingdom',
#   'Kingston upon Hull',
#   'Yorkshire and the Humber',
#   2011,
#   284321],
#  ['United Kingdom', 'Nottingham', 'East Midlands', 2011, 289301],
#  ['United Kingdom', 'Northampton', 'East Midlands', 2011, 215173],
#  ['United Kingdom', 'Leicester', 'East Midlands', 2011, 443760],
#  ['United Kingdom', 'Derby', 'East Midlands', 2011, 255394],
#  ['United Kingdom', 'Lincoln', 'East Midlands', 2011, 100160],
#  ['United Kingdom', 'Birmingham', 'West Midlands', 2011, 1085810],
#  ['United Kingdom', 'Coventry', 'West Midlands', 2011, 325949],
#  ['United Kingdom', 'Wolverhampton', 'West Midlands', 2011, 210319],
#  ['United Kingdom', 'Solihull', 'West Midlands', 2011, 123187],
#  ['United Kingdom', 'Stoke-on-Trent', 'West Midlands', 2011, 270726],
#  ['United Kingdom', 'Worcester', 'West Midlands', 2011, 100153],
#  ['United Kingdom', 'Sutton Coldfield', 'West Midlands', 2011, 109015],
#  ['United Kingdom', 'Telford', 'West Midlands', 2011, 142723],
#  ['United Kingdom', 'Cambridge', 'East of England', 2011, 145818],
#  ['United Kingdom', 'Peterborough', 'East of England', 2011, 161707],
#  ['United Kingdom', 'Ipswich', 'East of England', 2011, 144957],
#  ['United Kingdom', 'Chelmsford', 'East of England', 2011, 110507],
#  ['United Kingdom', 'Watford', 'East of England', 2011, 131982],
#  ['United Kingdom', 'Southend-on-Sea', 'East of England', 2011, 175547],
#  ['United Kingdom', 'Basildon', 'East of England', 2011, 107123],
#  ['United Kingdom', 'Colchester', 'East of England', 2011, 119441],
#  ['United Kingdom', 'Norwich', 'East of England', 2011, 186682],
#  ['United Kingdom', 'Luton', 'East of England', 2011, 211228],
#  ...]

# %%
r = {}
for e in document.iterfind('country'):
    name = e.find('name')
    for city in e.iterfind('city'):
        lk =
